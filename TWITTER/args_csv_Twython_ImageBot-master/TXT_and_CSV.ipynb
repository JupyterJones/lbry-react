# %%
https://support.smartbear.com/testcomplete/docs/scripting/working-with/strings/python.html

# %%
# %reset -f

# %%
# !mv ../deep-dream-generator/notebooks/CVS_DATA ../deep-dream-generator/notebooks/CSV_DATA

# %%
# %%writefile psyc.txt
#
# Do you often long for excitement?
# Do you often need understanding friends to cheer you up?
# Are you usually carefree?
# Do you find it very hard to take no for an answer?
# Do you stop and think things over before doing anything?
# If you say you will do something do you always keep your promise,no matter how inconvenient it might be to do so?
# Do your moods go up and down?
# Do you generally do and say things quickly without stopping to think?
# Do you ever feel just miserable for no good reason?
# Would you do almost anything for a dare?
# Do you suddenly feel shy when you want to talk to an attractive stranger?
# Once in a while do you lose your temper and get angry?
# Do you often do things on the spur of the moment?
# Have you ever used the term bible-thumper?
# Do you often worry about things you should have done or said?
# Generally do you prefer reading to meeting people?
# Are your feelings rather easily hurt?
# Do you like going out a lot?
# Do you occasionally have thoughts and ideas that you would not like otherpeople to know about?
# Are you sometimes bubbling over with energy and sometimes very sluggish?
# Do you prefer to have few but special friends?
# Do you daydream a lot?
# Do you believe life begans at 40?
# Are you one of those people that often say KARMA?
# Do you have many friends that are not in your age group?
# When people shout at you do you shout back?
# Is you your belief an eye for an eye?
# Do you think you kill another person?
# Do you pick through your food?
# Is waste not want not a way of life for you?
# Do you always empty your plate at a buffet meal?
# Do you raise your voice to intimidate others?
# Have you ever had to beg for anything?
# Have you ever prayed to God for a foolish thing?
# Have you done anything that could have given you serious jail time if you had been caught?
# Have you been to jail?
# Are you often troubled about feelings of guilt?
# Are all your habits good and desirable ones?
# Can you usually let yourself go and enjoy yourself a lot at a lively party?
# Would you call yourself tense or highly strung?
# Do other people think of you as being very lively?
# After you have done something important, do you come away feelingyou could have done better?
# Are you mostly quiet when you are with other people?
# Do you sometimes gossip?
# Do ideas run through your head so that you cannot sleep?
# If there is something you want to know about, would you rather look it upin a book than talk to someone about it?
# Do you get palpitations or thumping in your hear?
# Do you like the kind of work that you need to pay close attention to?
# Do you get attacks of shaking or trembling?
# Do you have a fear of law enforcement?
# Do you ever strick poses in the mirror?
# Would you always declare everything at customs, even if you knewyou could never be found out?
# Do you hate being with a crowd who play jokes on one another?
# Are you an irritable person?
# Would you allow a person to cut-in-line in front of you?
# Do you do recreational drugs?
# Do you get angry at traffic?
# Do you and is it often you give the finger in anger?
# Would you accept praise for an idea even if it was not your idea?
# Have you ever physically fought for fun?
# Have you ever been hurt another person for no reason?
# Do you hit or kick things?
# Do you ever practice expressions or ways to speak in the mirror?
# Do you have a tendency to avoid mirrors?
# Have you ever claimed an idea was yours when it was not?
# Are you afraid of the Dark?
# Do you have any secrets so dark they could destroy your happiness?
# Are you a believer that `Life is Good`?
# Do you have any serious regrets in your life?
# Are you addicted to work, internet, porn or drugs?
# Have you ever been `caught` at something that humiliated you?
# Do you ever sneak around?
# Have you ever hurt an animal from anger or worse yet just for fun?
# When strangers smile at you do you smile back?
# Are you uncomfortable in crowds?
# Have you a fear of public speaking?
# Do you try to avoid eye contact?
# Have you ever opened a wallet or purse that was not yours just because you were nosey?
# Would you sneak a peak at another persons private diary?
# Do you like doing things in which you have to act quickly?
# Do you worry about awful things that might happen?
# Are you slow and unhurried in the way you move?
# Have you ever been late for an appointment or work?
# Do you have many nightmares?
# Do you physically pat another person for there accomplishments?
# Have you ever said, I would never do that, when really you would?
# Have you ever said you hated someone when it was a lie?
# Are you afraid of spiders or snakes?
# Have you ever been hurt by another person for no reason?
# Are you a vengful person?
# Do you like talking to people so much that you never miss a chance of talking to a stranger?
# Are you troubled by aches and pains?
# Would you be very unhappy if you could not see lots of people most of the time?
# Would you call yourself a nervous person?
# Do you sleep well at night?
# Do you often shake your head at others?
# Of all the people you know, are there some whom you definitely do not like?
# Would you say that you were fairly self-confident?
# Are you easily hurt when people find fault with you or your work?
# Do you find it hard to really enjoy yourself at a lively party?
# Are you troubled by feelings of inferiority?
# Can you easily get some life into a dull party?
# Do you sometimes talk about things you know nothing about?
# Do you worry about your health?
# Do you like playing pranks on others?
# Did you ever make someone angry just for fun?
# Are you a person that likes to tease?
# Do you use the term just kidding quite often?
# Are you a personthat says I told you so?
# Do you suffer from sleeplessness?
# Do you believe in love at first sight?
# Do you get angry at inanimate items?
# Have you ever hit an inanimate object from anger?
# would you tell someone a lie to make them fell better?

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF

import numpy as np
import pandas as pd
CSV = "../deep-dream-generator/notebooks/CSV_DATA/psych/epi.dictionary.csv"

df = pd.read_csv(CSV)

sample_data_table = FF.create_table(df.head(100))
py.iplot(sample_data_table, filename='sample-data-table')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~madhatterstamps/4.embed" height="1790px" width="100%"></iframe>

# %%
trace = go.Bar(x = df['MIA'], y = df['LAX'],
                  name='co2.csv')
layout = go.Layout(title='co2',
                   plot_bgcolor='rgb(230, 230,230)', 
                   showlegend=True)
fig = go.Figure(data=[trace], layout=layout)

py.iplot(fig, filename='Co2 increase over years')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~madhatterstamps/18.embed" height="525px" width="100%"></iframe>

# %%
# !ls ../deep-dream-generator/notebooks/CSV_DATA/psych
# Out:
# ability.csv	    cubits.csv		Harman.8.csv	      Reise.csv
# affect.csv	    cushny.csv		Harman.political.csv  sat.act.csv
# Bechtoldt.1.csv     Dwyer.csv		heights.csv	      Schmid.csv
# Bechtoldt.2.csv     epi.bfi.csv		Holzinger.9.csv       Thurstone.33.csv
# Bechtoldt.csv	    epi.csv		Holzinger.csv	      Thurstone.csv
# bfi.csv		    epi.dictionary.csv	income.csv	      Tucker.csv
# bfi.dictionary.csv  galton.csv		iqitems.csv	      withinBetween.csv
# blot.csv	    Gleser.csv		msq.csv
# burt.csv	    Gorsuch.csv		neo.csv
# cities.csv	    Harman.5.csv	peas.csv

# %%
PATH= "../deep-dream-generator/notebooks/CSV_DATA/datasets/cities.csv"

photo = open(PATH,'rb')

# %%
filename = "../deep-dream-generator/notebooks/CSV_DATA/datasets/LakeHuron.csv"
with open(filename) as myfile:
    head = [next(myfile) for x in xrange(4)]
print head
# Out:
# ['"","time","LakeHuron"\n', '"1",1875,580.38\n', '"2",1876,581.86\n', '"3",1877,580.97\n']

# %%
# %load ../deep-dream-generator/notebooks/CSV_DATA/datasets/co2.csv
"","time","co2"
"1",1959,315.42
"2",1959.08333333334,316.31
"3",1959.16666666668,316.5
"4",1959.25000000002,317.56
"5",1959.33333333336,318.13
"6",1959.4166666667,318
"7",1959.50000000004,316.39
"8",1959.58333333338,314.65

# %%
filename = "../deep-dream-generator/notebooks/CSV_DATA/datasets/LakeHuron.csv"
with open(filename) as myfile:
    head = [next(myfile) for x in xrange(60)]
    mystring = ''.join(head)
    print mystring
# Out:
# "","time","LakeHuron"
# "1",1875,580.38
# "2",1876,581.86
# "3",1877,580.97
# "4",1878,580.8
# "5",1879,579.79
# "6",1880,580.39
# "7",1881,580.42
# "8",1882,580.82
# "9",1883,581.4
# "10",1884,581.32
# "11",1885,581.44
# "12",1886,581.68
# "13",1887,581.17
# "14",1888,580.53
# "15",1889,580.01
# "16",1890,579.91
# "17",1891,579.14
# "18",1892,579.16
# "19",1893,579.55
# "20",1894,579.67
# "21",1895,578.44
# "22",1896,578.24
# "23",1897,579.1
# "24",1898,579.09
# "25",1899,579.35
# "26",1900,578.82
# "27",1901,579.32
# "28",1902,579.01
# "29",1903,579
# "30",1904,579.8
# "31",1905,579.83
# "32",1906,579.72
# "33",1907,579.89
# "34",1908,580.01
# "35",1909,579.37
# "36",1910,578.69
# "37",1911,578.19
# "38",1912,578.67
# "39",1913,579.55
# "40",1914,578.92
# "41",1915,578.09
# "42",1916,579.37
# "43",1917,580.13
# "44",1918,580.14
# "45",1919,579.51
# "46",1920,579.24
# "47",1921,578.66
# "48",1922,578.86
# "49",1923,578.05
# "50",1924,577.79
# "51",1925,576.75
# "52",1926,576.75
# ...

# %%
import csv
help(csv)
# Out:
# Help on module csv:
#
# NAME
#     csv - CSV parsing and writing.
#
# FILE
#     /home/jack/anaconda2/lib/python2.7/csv.py
#
# MODULE DOCS
#     https://docs.python.org/library/csv
#
# DESCRIPTION
#     This module provides classes that assist in the reading and writing
#     of Comma Separated Value (CSV) files, and implements the interface
#     described by PEP 305.  Although many CSV files are simple to parse,
#     the format is not formally defined by a stable specification and
#     is subtle enough that parsing lines of a CSV file with something
#     like line.split(",") is bound to fail.  The module supports three
#     basic APIs: reading, writing, and registration of dialects.
#
#
#     DIALECT REGISTRATION:
#
#     Readers and writers support a dialect argument, which is a convenient
#     handle on a group of settings.  When the dialect argument is a string,
#     it identifies one of the dialects previously registered with the module.
# ...

# %%
import csv
help(csv.Dialect)
# Out:
# Help on class Dialect in module csv:
#
# class Dialect
#  |  Describe an Excel dialect.
#  |
#  |  This must be subclassed (see csv.excel).  Valid attributes are:
#  |  delimiter, quotechar, escapechar, doublequote, skipinitialspace,
#  |  lineterminator, quoting.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  delimiter = None
#  |
#  |  doublequote = None
#  |
#  |  escapechar = None
#  |
#  |  lineterminator = None
#  |
#  |  quotechar = None
#  |
#  |  quoting = None
#  |
#  |  skipinitialspace = None

# %%
import csv
CsvPath ="../deep-dream-generator/notebooks/CSV_DATA/datasets/co2.csv"
with open(CsvPath) as f:
    reader = csv.reader(f)
    for row in reader:
        #print(row)
        print row
# Out:
# ['', 'time', 'co2']
# ['1', '1959', '315.42']
# ['2', '1959.08333333334', '316.31']
# ['3', '1959.16666666668', '316.5']
# ['4', '1959.25000000002', '317.56']
# ['5', '1959.33333333336', '318.13']
# ['6', '1959.4166666667', '318']
# ['7', '1959.50000000004', '316.39']
# ['8', '1959.58333333338', '314.65']
# ['9', '1959.66666666672', '313.68']
# ['10', '1959.75000000006', '313.18']
# ['11', '1959.8333333334', '314.66']
# ['12', '1959.91666666675', '315.43']
# ['13', '1960.00000000009', '316.27']
# ['14', '1960.08333333343', '316.81']
# ['15', '1960.16666666677', '317.42']
# ['16', '1960.25000000011', '318.87']
# ['17', '1960.33333333345', '319.87']
# ['18', '1960.41666666679', '319.43']
# ['19', '1960.50000000013', '318.01']
# ['20', '1960.58333333347', '315.74']
# ['21', '1960.66666666681', '314']
# ['22', '1960.75000000015', '313.68']
# ['23', '1960.83333333349', '314.84']
# ['24', '1960.91666666683', '316.03']
# ['25', '1961.00000000017', '316.73']
# ...

# %%
from datetime import timedelta, datetime
def ConvertDecimalYear(number):
    year = int(number)
    d = timedelta(days=(number - year)*365)
    day_one = datetime(year,1,1)
    date = d + day_one
    without = date.replace(microsecond=0)
    return without

dateInDecimals = 1972.33333333448
print convert_partial_year(dateInDecimals)
# Out:
# 1972-05-01 16:00:00

# %%
import calendar
fract = .571772758385
days=(365.25*fract)+30.4166;months = (days/30.4166)
wholeMonth = int(months);monthname=calendar.month_name[wholeMonth]

days=(months-wholeMonth)*24;wholeDay= int(days)
hours = (days-wholeDay)*60;wholeHour=int(hours)
minutes = (hours-wholeHour)*60;minute = int(minutes)

sec = int((minutes-minute)*60)

print "Date:",monthname,wholeDay,wholeHour,minute,sec
# Out:
# Date: July 20 47 1 19

# %%
import calendar
import re
fract = .571772758385
days=365*fract
print "Total Days :",days
months = x/30.5
wholeMonth = int(months)
monthname=calendar.month_name[wholeMonth]
print "Month :",monthname
days=(months-wholeMonth)*24
wholeDay= int(days)
print "Days :",wholeDay
hours = (days-wholeDay)*24
wholeHour=int(hours)
print "Hour :",wholeHour
minute = hours-wholeHour
print hours
minutes = int(hours-wholeHour)
print "Minutes :",minutes
sec = int(minute*60)
print "Seconds :",sec
print months-wholeMonth
#def month(wholeMonth)



str= "Date :", monthname,",",wholeDay,",",wholeHour,",",minutes,",",sec 
str= wholeMonth,",",wholeDay,",",wholeHour,",",minutes,",",sec 

#print "".join(str)
str = map(int, str)
# Out:
# Total Days : 208.697056811
# Month : January
# Days : 22
# Hour : 10
# 10.2295081967
# Minutes : 0
# Seconds : 13
# 0.934426229508
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-a525adc513ae> in <module>()
#      29
#      30 #print "".join(str)
# ---> 31 str = map(int, str)
#
# ValueError: invalid literal for int() with base 10: ','

# %%
from datetime import timedelta, datetime

def convert_partial_year(number):

    year = int(number)
    d = timedelta(days=(number - year)*365)
    day_one = datetime(year,1,1)
    date = d + day_one
    return date

print convert_partial_year(1970.75020)
# Out:
# 1970-10-01 19:45:07.199998

# %%
import pandas as pd
from datetime import datetime
import csv
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
CsvPath ="../deep-dream-generator/notebooks/CSV_DATA/datasets/co2.csv"
#df = pd.read_csv(CsvPath,  usecols="co2")
data = pd.read_csv(CsvPath, usecols=[2])
print data.to_string(index=False)
# Out:
# co2
# 315.42
# 316.31
# 316.50
# 317.56
# 318.13
# 318.00
# 316.39
# 314.65
# 313.68
# 313.18
# 314.66
# 315.43
# 316.27
# 316.81
# 317.42
# 318.87
# 319.87
# 319.43
# 318.01
# 315.74
# 314.00
# 313.68
# 314.84
# 316.03
# 316.73
# 317.54
# 318.38
# 319.31
# 320.42
# 319.61
# 318.42
# 316.63
# 314.83
# 315.16
# 315.94
# 316.85
# 317.78
# 318.40
# 319.53
# 320.42
# 320.85
# 320.45
# 319.45
# 317.25
# 316.11
# 315.27
# 316.53
# 317.53
# 318.58
# 318.92
# 319.70
# 321.22
# 322.08
# 321.31
# 319.58
# 317.61
# 316.05
# 315.83
# 316.91
# 318.20
# 319.41
# 320.07
# 320.74
# 321.40
# 322.06
# 321.73
# 320.27
# 318.54
# 316.54
# 316.71
# 317.53
# 318.55
# 319.27
# 320.28
# 320.73
# 321.97
# 322.00
# 321.71
# 321.05
# 318.71
# 317.66
# 317.14
# 318.70
# 319.25
# 320.46
# 321.43
# 322.23
# 323.54
# 323.91
# 323.59
# 322.24
# 320.20
# 318.48
# 317.94
# 319.63
# 320.87
# 322.17
# 322.34
# 322.88
# 324.25
# 324.83
# 323.93
# 322.38
# 320.76
# 319.10
# 319.24
# 320.56
# 321.80
# 322.40
# 322.99
# ...

# %%
# %%writefile ArgTest.py
#!/usr/bin/python
import sys

#for arg in sys.argv[1:]:
#    print arg[0:]
    #print arg
    #print arg[1:],"\n", arg[0:]
    #print arg
    #print arg[:0]
    #print arg[0:]
#print sys.argv[0:]
#print sys.argv[1:]
a,b = sys.argv[1:]
a=int(a);b=int(b)
print a+b
# Out:
# Overwriting ArgTest.py

# %%
# !python ArgTest.py 455 6
# Out:
# 461

# %%
# %%writefile ArgTest.py
#!/usr/bin/python
import sys
def main():
    # print command line arguments
    for arg in sys.argv[1:]:
        print arg[0:]
        #print arg
        #print arg[1:],"\n", arg[0:]
        #print arg
        #print arg[:0]
        #print arg[0:]
if __name__ == "__main__":
    main()
# Out:
# Overwriting ArgTest.py

# %%
# !python ArgTest.py 455 455 6 64 54
# Out:
# 455
# 455
# 6
# 64
# 54

# %%
import pandas as pd
from datetime import datetime
import csv
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
CsvPath ="../deep-dream-generator/notebooks/CSV_DATA/datasets/co2.csv"
#df = pd.read_csv(CsvPath,  usecols="co2")
data = pd.read_csv(CsvPath, usecols=[2])
#df = data.to_string(index=False)
#df = data.to_int(index=False)
#import matplotlib.pyplot as plt
#plt.plot([df])
data.iloc[:,[1,3]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-360-77efb9f15ea1> in <module>()
#      11 #import matplotlib.pyplot as plt
#      12 #plt.plot([df])
# ---> 13 data.iloc[:,[1,3]]
#
# /home/jack/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# /home/jack/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#    1660     def _getitem_tuple(self, tup):
#    1661
# -> 1662         self._has_valid_tuple(tup)
#    1663         try:
#    1664             return self._getitem_lowerdim(tup)
#
# ...

# %%
import pandas as pd
from datetime import datetime
import csv
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
df = pd.read_csv("../deep-dream-generator/notebooks/CSV_DATA/datasets/co2.csv",  usecols="co2")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-359-c18e33526a81> in <module>()
#       4 import matplotlib.pyplot as plt
#       5 import matplotlib.dates as mdates
# ----> 6 df = pd.read_csv("../deep-dream-generator/notebooks/CSV_DATA/datasets/co2.csv",  usecols="co2")
#
# ...

# %%
filename = "../deep-dream-generator/notebooks/CSV_DATA/datasets/co2.csv"
with open(filename) as myfile:
    head = [next(myfile) for x in xrange(86)]
    mystring = ''.join(head)
    print mystring
# Out:
# "","time","co2"
# "1",1959,315.42
# "2",1959.08333333334,316.31
# "3",1959.16666666668,316.5
# "4",1959.25000000002,317.56
# "5",1959.33333333336,318.13
# "6",1959.4166666667,318
# "7",1959.50000000004,316.39
# "8",1959.58333333338,314.65
# "9",1959.66666666672,313.68
# "10",1959.75000000006,313.18
# "11",1959.8333333334,314.66
# "12",1959.91666666675,315.43
# "13",1960.00000000009,316.27
# "14",1960.08333333343,316.81
# "15",1960.16666666677,317.42
# "16",1960.25000000011,318.87
# "17",1960.33333333345,319.87
# "18",1960.41666666679,319.43
# "19",1960.50000000013,318.01
# "20",1960.58333333347,315.74
# "21",1960.66666666681,314
# "22",1960.75000000015,313.68
# "23",1960.83333333349,314.84
# "24",1960.91666666683,316.03
# "25",1961.00000000017,316.73
# "26",1961.08333333351,317.54
# "27",1961.16666666685,318.38
# "28",1961.25000000019,319.31
# "29",1961.33333333353,320.42
# "30",1961.41666666687,319.61
# "31",1961.50000000021,318.42
# "32",1961.58333333355,316.63
# ...

# %%
list = [[356], ['b'], ['c']]
newList = [l[0] for l in list]
print newList
# Out:
# [356, 'b', 'c']

# %%
# The 365 MUST be a string not a number
List = [['365'], ['b'], ['c']]
newList = [l[0] for l in List]
Simple = (", ".join(newList))
print Simple
# Out:
# 365, b, c

# %%
List = [[356], ['b'], ['c']]
",".join(str(x) for x in List)
# Out:
# "[356],['b'],['c']"

# %%
List = [['a'], ['b'], ['c']]
newList = [l[0] for l in List]
Simple = (" ".join(newList))
print Simple
# Out:
# a b c

# %%
List = [[356], ['b'], ['c']]
str(List)
# Out:
# "[[356], ['b'], ['c']]"

# %%
#A great variety can be done with this 1:-1 for instance 4:-2 removes the first 4 and last 2
List = [[356], ['b'], ['c']]
newstring = ",".join(str(x) for x in List)

print str(newstring)[1:-1]
# Out:
# 356],['b'],['c'

# %%
List = [['this'], ['is'], ['testing']]
newList = [l[0] for l in List]
Simple = (" ".join(newList))
print Simple
# Out:
# this is testing

# %%
import ast
List = [['a'], ['b'], ['c']]
ast.literal_eval(repr(List))
# Out:
# [['a'], ['b'], ['c']]

# %%
List = [[356], ['b'], ['c']]
",".join(str(x) for x in List)
# Out:
# "[356],['b'],['c']"

# %%
List = [[356], ['b'], ['c']]
Simple1 = ",".join(str(x) for x in List)
Simple = Simple1.translate(None, "[]'")
print Simple
# Out:
# 356,b,c

# %%
strinG = "This can remove the same character throughout the text string in this case, aeio and u"
strinG.translate(None, 'aeiou')
# Out:
# 'Ths cn rmv th sm chrctr thrght th txt strng n ths cs,  nd  '

# %%
strinG = "This can remove the characters from the beginning and end of the text, then convert everything to uppercase"
strinG = strinG.replace('This can', '')[:-38].upper()
print strinG
# Out:
#  REMOVE THE CHARACTERS FROM THE BEGINNING AND END OF THE TEXT

# %%
strinG = "This can remove the characters from the beginning and end of the text"

strinG = strinG[:strinG.find('nning') + 1]
print strinG
# Out:
# This can remove the characters from the begin

# %%
import string
import re
strinG = {'This can remove the characters from the beginning and end or middle of the text'}

newString = {x.replace('remove', 'replace').replace('characters', 'letters') for x in strinG}
print newString
# Out:
# set(['This can replace the letters from the beginning and end or middle of the text'])

# %%
import string
import re
strinG = {'This can remove the characters from the beginning and end or middle of the text'}

newString = {x.replace('remove', 'replace').replace('characters', 'letters') for x in strinG}
print newString
print "\n","Notice what the last line did. I got rid of the 'set id'","\n"
print str(newString)[6:-3]
# Out:
# set(['This can replace the letters from the beginning and end or middle of the text'])
#
# Notice what the last line did. I got rid of the 'set id'
#
# This can replace the letters from the beginning and end or middle of the text

# %%
strinG = 'This can remove the characters from the center of the text'
newstring = strinG[:15] + strinG[19:]
print newstring , "\n" , strinG[:15] , "\n" , strinG[19:]
# Out:
# This can remove characters from the center of the text
# This can remove
#  characters from the center of the text

# %%
filename = "../deep-dream-generator/notebooks/CSV_DATA/datasets/co2.csv"
with open(filename, mode="r") as my_file:
    for line in my_file:
        print(line)
# Out:
# "","time","co2"
#
# "1",1959,315.42
#
# "2",1959.08333333334,316.31
#
# "3",1959.16666666668,316.5
#
# "4",1959.25000000002,317.56
#
# "5",1959.33333333336,318.13
#
# "6",1959.4166666667,318
#
# "7",1959.50000000004,316.39
#
# "8",1959.58333333338,314.65
#
# "9",1959.66666666672,313.68
#
# "10",1959.75000000006,313.18
#
# "11",1959.8333333334,314.66
#
# "12",1959.91666666675,315.43
#
# "13",1960.00000000009,316.27
#
# "14",1960.08333333343,316.81
#
# "15",1960.16666666677,317.42
#
# "16",1960.25000000011,318.87
#
# "17",1960.33333333345,319.87
#
# "18",1960.41666666679,319.43
#
# "19",1960.50000000013,318.01
#
# "20",1960.58333333347,315.74
#
# "21",1960.66666666681,314
#
# "22",1960.75000000015,313.68
#
# "23",1960.83333333349,314.84
#
# "24",1960.91666666683,316.03
#
# "25",1961.00000000017,316.73
#
# "26",1961.08333333351,317.54
#
# "27",1961.16666666685,318.38
#
# "28",1961.25000000019,319.31
#
# "29",1961.33333333353,320.42
#
# "30",1961.41666666687,319.61
#
# ...

# %%
## Open the file with read only permit
import sys
filename = "../deep-dream-generator/notebooks/CSV_DATA/datasets/co2.csv"
f = open(filename)
## Read the first line 
line = f.readline()
with open(filename) as myfile:
    head = list(islice(myfile,1))
print head

## If the file is not empty keep reading line one at a time
## till the file is empty
x = 0
while line :
    while x <5:
        line = f.readline()
        x = x +1 
        print line
        
    f.close()
    sys.exit()
# Out:
# ['"","time","co2"\n']
# "1",1959,315.42
#
# "2",1959.08333333334,316.31
#
# "3",1959.16666666668,316.5
#
# "4",1959.25000000002,317.56
#
# "5",1959.33333333336,318.13
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
# %%writefile test.data
# [315.42,
# 316.31,
# 316.5,
# 317.56,
# 318.13,
# 318,
# 316.39,
# 314.65,
# 313.68,
# 313.18,
# 314.66,
# 315.43,
# 316.27,
# 316.81,
# 317.42,
# 318.87,
# 319.87,
# 319.43,
# 318.01,
# 315.74,
# 314,
# 313.68,
# 314.84,
# 316.03,
# 316.73,
# 317.54,
# 318.38,
# 319.31,
# 320.42,
# 319.61,
# 318.42,
# 316.63,
# 314.83,
# 315.16,
# 315.94,
# 316.85,
# 317.78,
# 318.4,
# 319.53,
# 320.42,
# 320.85,
# 320.45,
# 319.45,
# 317.25,
# 316.11,
# 315.27,
# 316.53,
# 317.53,
# 318.58,
# 318.92,
# 319.7,
# 321.22,
# 322.08,
# 321.31,
# 319.58,
# 317.61,
# 316.05,
# 315.83,
# 316.91,
# 318.2,
# 319.41,
# 320.07,
# 320.74,
# 321.4,
# 322.06,
# 321.73,
# 320.27,
# 318.54,
# 316.54,
# 316.71,
# 317.53,
# 318.55,
# 319.27,
# 320.28,
# 320.73,
# 321.97,
# 322,
# 321.71,
# 321.05,
# 318.71,
# 317.66,
# 317.14,
# 318.7,
# 319.25,
# 320.46]
# Out:
# Overwriting test.data

# %%
https://www.computerhope.com/issues/ch001721.htm

# %%
import matplotlib.pyplot as plt
filename = "test.data"
fileN = open("filename", "w")
plt.plot([fileN
         ])
plt.ylabel('CO2 Levels')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-280-3712e404435a> in <module>()
#       2 filename = "test.data"
#       3 fileN = open("filename", "w")
# ----> 4 plt.plot([fileN
#       5          ])
#       6 plt.ylabel('CO2 Levels')
#
# /home/jack/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# /home/jack/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
# ...

# %%
import matplotlib.pyplot as plt
plt.plot([
315.42,
316.31,
316.5,
317.56,
318.13,
318,
316.39,
314.65,
313.68,
313.18,
314.66,
315.43,
316.27,
316.81,
317.42,
318.87,
319.87,
319.43,
318.01,
315.74,
314,
313.68,
314.84,
316.03,
316.73,
317.54,
318.38,
319.31,
320.42,
319.61,
318.42,
316.63,
314.83,
315.16,
315.94,
316.85,
317.78,
318.4,
319.53,
320.42,
320.85,
320.45,
319.45,
317.25,
316.11,
315.27,
316.53,
317.53,
318.58,
318.92,
319.7,
321.22,
322.08,
321.31,
319.58,
317.61,
316.05,
315.83,
316.91,
318.2,
319.41,
320.07,
320.74,
321.4,
322.06,
321.73,
320.27,
318.54,
316.54,
316.71,
317.53,
318.55,
319.27,
320.28,
320.73,
321.97,
322,
321.71,
321.05,
318.71,
317.66,
317.14,
318.7,
319.25,
320.46
])

plt.ylabel('CO2 Levels')
plt.show()

# %%
# %%writefile test.data
# 315.42,
# 316.31,
# 316.5,
# 317.56,
# 318.13,
# 318,
# 316.39,
# 314.65,
# 313.68,
# 313.18,
# 314.66,
# 315.43,
# 316.27,
# 316.81,
# 317.42,
# 318.87,
# 319.87,
# 319.43,
# 318.01,
# 315.74,
# 314,
# 313.68,
# 314.84,
# 316.03,
# 316.73,
# 317.54,
# 318.38,
# 319.31,
# 320.42,
# 319.61,
# 318.42,
# 316.63,
# 314.83,
# 315.16,
# 315.94,
# 316.85,
# 317.78,
# 318.4,
# 319.53,
# 320.42,
# 320.85,
# 320.45,
# 319.45,
# 317.25,
# 316.11,
# 315.27,
# 316.53,
# 317.53,
# 318.58,
# 318.92,
# 319.7,
# 321.22,
# 322.08,
# 321.31,
# 319.58,
# 317.61,
# 316.05,
# 315.83,
# 316.91,
# 318.2,
# 319.41,
# 320.07,
# 320.74,
# 321.4,
# 322.06,
# 321.73,
# 320.27,
# 318.54,
# 316.54,
# 316.71,
# 317.53,
# 318.55,
# 319.27,
# 320.28,
# 320.73,
# 321.97,
# 322,
# 321.71,
# 321.05,
# 318.71,
# 317.66,
# 317.14,
# 318.7,
# 319.25,
# 320.46
# Out:
# Writing test.data

# %% [markdown]
# # Some Helpful Utility Ideas

# %%
# If division result is desired as a float
from __future__ import division
a = 360/365
print a
# Out:
# 0.986301369863

# %%
#convert date to fraction of years
from datetime import datetime
d = datetime(2017, 6, 28, 0, 0, 0)
(float(d.strftime("%j"))-1) / 366 + float(d.strftime("%Y"))
# Out:
# 2017.4863387978141

# %%
#convert date to fraction of years
from datetime import datetime
d = datetime(2017, 6, 28, 0, 0, 0)
(float(d.strftime("%j"))-1) / 366 + float(d.strftime("%Y"))
# Out:
# 2017.4863387978141

# %%
# %%writefile ArgTest.py
import sys
import numpy as np
import sys
script = sys.argv[0]
filename = sys.argv[1]

def main():
    script = sys.argv[0]
    filename = sys.argv[1]
    #data = np.loadtxt(filename, delimiter=',')
    #for m in data.mean(axis=1):
    print script , filename
    if __name__ == __main__ :
        main()    
        print script , filename
# Out:
# Overwriting ArgTest.py

# %%
# !python ArgTest.py  eweewe

# %%
# %%writefile resize640.py
#!/usr/bin/python
__author__ = 'Jack Northrup'
import sys, getopt
from PIL import Image 
image=''
output=''

###############################
# o == option
# a == argument passed to the o
###############################
# Cache an error with try..except 
# Note: options is the string of option letters that the script wants to recognize, with 
# options that require an argument followed by a colon (':') i.e. -i fileName
#
try:
    myopts, args = getopt.getopt(sys.argv[1:],"i:o:")
except getopt.GetoptError as e:
    print (str(e))
    print("Usage: %s -i input -o output" % sys.argv[0])
    sys.exit(2)

for o, a in myopts:
    if o == '-i':
        image=a
    elif o == '-o':
        output=a

# Display input and output file name passed as the args
print ("Input file : %s and output file: %s" % (image,output) )
# Out:
# Overwriting resize640.py

# %%
import date2dec
help(date2dec)
#print date2dec.Date2Dec(4, 38)
# Out:
# Help on module date2dec:
#
# NAME
#     date2dec
#
# FILE
#     /home/jack/Desktop/imagebot/date2dec.py
#
# DESCRIPTION
#     #Very rough date to fraction of years
#     # no time just numder date
#
# FUNCTIONS
#     date2dec(MonthNum, Date)
#         #Very rough date to fraction of years
#         # no time just numder date
#
# DATA
#     fract = 0.4865160848733744

# %% [markdown]
# # Working

# %%
#  date2dec
#!/usr/local/bin/python
from __future__ import division
import sys
import math
import argparse
parser = argparse.ArgumentParser(description="""
Convert a date into a fraction of a year
Enter Number of Month and number of day (NO TIME) .
USAGE:
import date2dec
FractionOfYear = date2dec.date2dec(6,27)
print FractionOfYear
""")
args = parser.parse_args()

def date2dec():
    #MonthNum = int(sys.argv[1])
    #Date = int(sys.argv[2])
    
    mn = (MonthNum-1) * 30.14
    r = mn+DateI-1
    op = 365.25/r-365.25
    FractionOfYear = r/365.25
    return FractionOfYear
    
if __name__ == "__main__":
    MonthNum = int(raw_input("What month?"))
    DateI = int(raw_input("What day?"))
    date2dec()
    mn = (MonthNum-1) * 30.14
    r = mn+DateI-1
    op = 365.25/r-365.25
    FractionOfYear = r/365.25
    print FractionOfYear

# %%
# %%writefile dateTodec.py
#!/usr/local/bin/python
from __future__ import division
import sys
import math
import sys, getopt
MonthNum = int(sys.argv[1]) 
DateI = int(sys.argv[2])

"""
from PIL import Image 
MonthNum = sys.argv[1]
DateI = sys.argv[2]
x=int(MonthNum)
y=int(DateI)
print x, y
#!/usr/bin/python
import sys
MonthNum = int(sys.argv[1]) 
DateI = int(sys.argv[2])
"""

mn = (MonthNum-1)*30.14
r = mn+DateI-1
op = 365.25/r-365.25
print "fraction: ",r/365.25
print "\n"
print "Notice the change format of print after being turned into an object"
fraction = "fraction: ",r/365.25
print fraction
# Out:
# Overwriting dateTodec.py

# %%
# !python dateTodec.py 2  22
# Out:
# fraction:  0.140013689254
#
#
# Notice the change format of print after being turned into an object
# ('fraction: ', 0.14001368925393567)

# %%
# %%writefile mySum.py
#!/usr/bin/python
import sys
MonthNum = int(sys.argv[1]) 
DateI = int(sys.argv[2])


mn = (MonthNum-1)*30.14
r = mn+DateI-1
op = 365.25/r-365.25
print "fraction: ",r/365.25
print "\n"
print "Notice the change format of print after being turned into an object"
fraction = "fraction: ",r/365.25
print fraction
# Out:
# Overwriting mySum.py

# %%
# !python mySum.py 10 20
# Out:
# fraction:  0.794688569473
#
#
# Notice the change format of print after being turned into an object
# ('fraction: ', 0.7946885694729637)

# %%
# %reset -f
