# %% [markdown]
# # ONE TIME MANUAL POSTS

# %%
#ONE TIME MANUAL POSTS
#!/home/jack/anaconda2/python
import random
from random import randint
import time
import markovify
import os
import sys
sys.path.insert(1, "/home/jack/anaconda2/envs/py27/lib/python2.7/site-packages")
import twython
from twython import Twython
from PIL import Image, ImageChops, ImageDraw, ImageFont, ImageFilter

path = r"AUGpost/"
base_image = random.choice([
    x for x in os.listdir(path)
    if os.path.isfile(os.path.join(path, x))
])
filename0=(path+base_image)

custom = "junk/20170829123311.png"
filename0=(custom)
def generate_the_word(infile):
        with open(infile) as f:
            contents_of_file = f.read()
        lines = contents_of_file.splitlines()
        line_number = random.randrange(0, len(lines))
        return lines[line_number]

def draw_text_with_halo(img, position, text, font, col, halo_col):
    #halo = Image.new('RGBA', img.size, (0, 0, 0, 0))
    halo = Image.new('RGBA', img.size, (255,255,255, 0))
    ImageDraw.Draw(halo).text(position, text, font = font, fill = halo_col)
    blurred_halo = halo.filter(ImageFilter.BLUR)
    ImageDraw.Draw(blurred_halo).text(position, text, font = font, fill = col)
    return Image.composite(img, blurred_halo, ImageChops.invert(blurred_halo))

if __name__ == '__main__':
    inp = Image.open(filename0)
    font = ImageFont.truetype("/home/jack/.fonts/Exo-Black.ttf", 45)
    #font = ImageFont.truetype("/home/jack/.fonts/GRUNTREAPER.ttf", 70)
    #font = ImageFont.truetype("/home/jack/.fonts/Nightbird.ttf", 70)
    #font = ImageFont.truetype("/home/jack/.fonts/Nightbird.ttf", 70)
    #font = ImageFont.truetype("/home/jack/.fonts/Punktype.ttf", 70)
    text_col = (255,200,0) # bright green
    halo_col = (0, 0,0)   # black
    #text_col = (230, 230,250) # bright green
    #halo_col = (0,0,0)  # black (0,0,0)    
    textin = (generate_the_word("wordcloud.txt"))
    #i2 = draw_text_with_halo(inp, (15, 8), "HIGH FIVE", font, text_col, halo_col)
    i2 = draw_text_with_halo(inp, (20, 20), textin, font, text_col, halo_col)
    #txt = Image.new('RGBA', i.size, (255,255,255,0))

    # get a font
    fnt = ImageFont.truetype("/home/jack/.fonts/Exo-Black.ttf", 20)
    
    # get a drawing context
    width, height = inp.size
    marginx = 225
    marginy = 35
    x = width - marginx
    y = height - marginy
    signature_ = "The TwitterBot Project" 
    text_col2 = (15, 5, 10) # bright green
    halo_col2 = (255, 255,255) 
    #text_col2 = (255, 255,255) # signature white
    #halo_col2 = (0, 0, 0)   # signature black
    txt=draw_text_with_halo(i2,(x,y), signature_, fnt, text_col2, halo_col2)
    out = Image.alpha_composite(i2, txt)
    out.save("tmp/TM_POST.jpg")

#removed keys for privacy reasons
CONSUMER_KEY = 'xxxxxxxxxxx'
CONSUMER_SECRET = 'xxxxxxxxxxxx'
ACCESS_KEY = 'xxxxxxxxxxxxxx'
ACCESS_SECRET = 'xxxxxxxxxxxxxx'



twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_KEY, ACCESS_SECRET)
#path = 'images/NewFolder'
f = open("art.txt")
text = f.read()
# Build the model.
text_model = markovify.Text(text)
# Print randomly-generated sentences of no more than 140 characters
#http://paulbourke.net/fractals/
#STR = (text_model.make_short_sentence(140))
#STR = ("$Python $Imagery $Redneck #filipina #filipinowoman posted with #JupyterNotebook.")
STR = (generate_the_word("key.txt"))
#PATH = "/home/jack/Desktop/deep-dream-generator/notebooks/STUFF/experiment/experiment8.jpg"
PATH = "tmp/TM_POST.jpg"
# 1 , 2, 3, 12, 5, 15, 8, 6
#photo = open('/home/jack/Desktop/deep-dream-generator/notebooks/images/'+file_list[rnd]+'.jpg','rb')

photo = open(PATH,'rb')
response = twitter.upload_media(media=photo)
twitter.update_status(status=STR, media_ids=[response['media_id']])
# !showme tmp/TM_POST.jpg

# %%
    # !locate *.ttf
# Out:
# /etc/alternatives/fonts-japanese-gothic.ttf
# /home/jack/.appdata/edu.media.mit.Scratch2Editor/Local Store/static/fonts/scratch-icons.ttf
# /home/jack/.config/google-chrome/Default/Extensions/bfbameneiokkgbdmiekhjnmfkcnldhhm/0.5_0/common/fonts/fontawesome-webfont.ttf
# /home/jack/.config/google-chrome/Default/Extensions/cnpdaoipdfbkpdbdpmceeejdaabiebcb/2.6.1_0/css/font-awesome/fonts/fontawesome-webfont.ttf
# /home/jack/.config/google-chrome.junk/Default.junk/Extensions/bfbameneiokkgbdmiekhjnmfkcnldhhm/0.4.8_0/common/fonts/fontawesome-webfont.ttf
# /home/jack/.config/google-chrome.junk/Default.junk/Extensions/cnpdaoipdfbkpdbdpmceeejdaabiebcb/2.6.1_0/css/font-awesome/fonts/fontawesome-webfont.ttf
# /home/jack/.config/google-chrome.junk/Default.junk/Extensions/nnhinecjpcncdkchdidimohngcbkjalb/1.9_0/fonts/Billabong.ttf
# /home/jack/.config/google-chrome.junk/Default.junk/Extensions/nnhinecjpcncdkchdidimohngcbkjalb/1.9_0/fonts/Roboto-Light.ttf
# /home/jack/.config/google-chrome.junk/Default.junk/Extensions/nnhinecjpcncdkchdidimohngcbkjalb/1.9_0/fonts/Roboto-Regular.ttf
# /home/jack/.config/google-chrome.junk/Default.junk/Extensions/nnhinecjpcncdkchdidimohngcbkjalb/1.9_0/fonts/Roboto-Thin.ttf
# /home/jack/.config/google-chrome.junk/Default.junk/Extensions/nnhinecjpcncdkchdidimohngcbkjalb/1.9_0/fonts/RobotoCondensed-Light.ttf
# /home/jack/.config/google-chrome.junk/Default.junk/Extensions/nnhinecjpcncdkchdidimohngcbkjalb/1.9_0/fonts/RobotoCondensed-Regular.ttf
# /home/jack/.config/sublime-text-3/Packages/Sublime-JSHint/scripts/node_modules/jsonminify/report/assets/font/fontawesome-webfont.ttf
# /home/jack/.fonts/1938 STeMPEL.ttf
# /home/jack/.fonts/3 theHard way RMX.ttf
# /home/jack/.fonts/Admiration Pains.ttf
# /home/jack/.fonts/Aerosol.ttf
# /home/jack/.fonts/Allura-Regular.ttf
# /home/jack/.fonts/Alpine.ttf
# /home/jack/.fonts/AngelicWar.ttf
# /home/jack/.fonts/AngloSaxonItalic.ttf
# /home/jack/.fonts/Anita semi square.ttf
# /home/jack/.fonts/Antique Quest St.ttf
# /home/jack/.fonts/Anton.ttf
# /home/jack/.fonts/Baldur Shadow.ttf
# /home/jack/.fonts/Baldur.ttf
# /home/jack/.fonts/BaroqueScript.ttf
# /home/jack/.fonts/Becker-Inline.ttf
# /home/jack/.fonts/Becker.ttf
# /home/jack/.fonts/BeckerShadow.ttf
# /home/jack/.fonts/Behrensschrift.ttf
# /home/jack/.fonts/Beyond Wonderland.ttf
# /home/jack/.fonts/BlackWidow.ttf
# /home/jack/.fonts/Bombing.ttf
# /home/jack/.fonts/BoogieNightsShadowNF.ttf
# /home/jack/.fonts/Burliweh Sans.ttf
# /home/jack/.fonts/CFMyBloodyValentine-Regular.ttf
# /home/jack/.fonts/CHEAP STEALER.ttf
# /home/jack/.fonts/COMPUTERRobot.ttf
# /home/jack/.fonts/CamelotDeNada.ttf
# /home/jack/.fonts/CantzleyAD1600.ttf
# /home/jack/.fonts/CarbonBlock.ttf
# /home/jack/.fonts/Cardinal-Alternate.ttf
# /home/jack/.fonts/Cardinal.ttf
# /home/jack/.fonts/ChicagoFLF.ttf
# /home/jack/.fonts/Cocaine sans.ttf
# /home/jack/.fonts/DESIB___.ttf
# /home/jack/.fonts/Damned.ttf
# /home/jack/.fonts/Daubmark.ttf
# /home/jack/.fonts/Demo_ConeriaScript.ttf
# /home/jack/.fonts/Demo_ConeriaScript_Slanted.ttf
# /home/jack/.fonts/DestroyEarthBB.ttf
# /home/jack/.fonts/DestroyEarthRoughBB.ttf
# /home/jack/.fonts/Deutsch.ttf
# /home/jack/.fonts/Diane de France.ttf
# /home/jack/.fonts/DorovarFLF-Carolus.ttf
# /home/jack/.fonts/DorovarFLF-Italic.ttf
# /home/jack/.fonts/ENDORALT.ttf
# /home/jack/.fonts/ENDOR___.ttf
# /home/jack/.fonts/El tercer hombre.ttf
# /home/jack/.fonts/EtBoemRU.ttf
# /home/jack/.fonts/Exo-Black.ttf
# /home/jack/.fonts/Exo-BlackItalic.ttf
# /home/jack/.fonts/Exo-Bold.ttf
# /home/jack/.fonts/Exo-BoldItalic.ttf
# /home/jack/.fonts/Exo-ExtraBold.ttf
# /home/jack/.fonts/Exo-ExtraBoldItalic.ttf
# /home/jack/.fonts/Exo-ExtraLight.ttf
# /home/jack/.fonts/Exo-ExtraLightItalic.ttf
# /home/jack/.fonts/Exo-Italic.ttf
# /home/jack/.fonts/Exo-Light.ttf
# /home/jack/.fonts/Exo-LightItalic.ttf
# /home/jack/.fonts/Exo-Medium.ttf
# /home/jack/.fonts/Exo-MediumItalic.ttf
# /home/jack/.fonts/Exo-Regular.ttf
# /home/jack/.fonts/Exo-SemiBold.ttf
# /home/jack/.fonts/Exo-SemiBoldItalic.ttf
# /home/jack/.fonts/Exo-Thin.ttf
# /home/jack/.fonts/Exo-ThinItalic.ttf
# /home/jack/.fonts/Eyes Wide Open Bold Personal Use.ttf
# /home/jack/.fonts/Eyes Wide Open Personal Use.ttf
# /home/jack/.fonts/FDT_Wonderland_DEMO_VERSION.ttf
# /home/jack/.fonts/Face Your Fears.ttf
# /home/jack/.fonts/False_Advertising.ttf
# /home/jack/.fonts/Fantasy Clipart.ttf
# /home/jack/.fonts/Flatwheat-Italic.ttf
# /home/jack/.fonts/Flatwheat-Regular.ttf
# /home/jack/.fonts/Flea Market Finds.ttf
# /home/jack/.fonts/FontleroyBrownNF.ttf
# /home/jack/.fonts/From Street Art.ttf
# /home/jack/.fonts/Fyodor-Bold.ttf
# /home/jack/.fonts/Fyodor-BoldCondensed.ttf
# /home/jack/.fonts/Fyodor-BoldCondensedOblique.ttf
# /home/jack/.fonts/Fyodor-BoldExpanded.ttf
# /home/jack/.fonts/Fyodor-BoldExpandedOblique.ttf
# /home/jack/.fonts/Fyodor-BoldOblique.ttf
# /home/jack/.fonts/GRUNTREAPER.ttf
# /home/jack/.fonts/Gentleman on the Rainbow.ttf
# /home/jack/.fonts/Germania Shadow.ttf
# /home/jack/.fonts/GristledFont-Regular.ttf
# /home/jack/.fonts/Hanged Letters.ttf
# /home/jack/.fonts/HighStyle.ttf
# /home/jack/.fonts/HighlandGothicFLF-Bold.ttf
# /home/jack/.fonts/HighlandGothicFLF.ttf
# /home/jack/.fonts/HighlandGothicLightFLF.ttf
# /home/jack/.fonts/IMMORTAL.ttf
# /home/jack/.fonts/IMMRTLT_.ttf
# /home/jack/.fonts/INSULA__.ttf
# /home/jack/.fonts/IntriqueScript_PersonalUse.ttf
# /home/jack/.fonts/JimNightshade-Regular.ttf
# /home/jack/.fonts/KasseFLF-Bold.ttf
# /home/jack/.fonts/KasseFLF.ttf
# /home/jack/.fonts/KasseUltraFLF.ttf
# /home/jack/.fonts/KellyAnnGothic.ttf
# /home/jack/.fonts/Kingthings Foundation.ttf
# /home/jack/.fonts/Kingthings Petrock.ttf
# /home/jack/.fonts/LABTSEBI.ttf
# /home/jack/.fonts/LABTSECB.ttf
# /home/jack/.fonts/LABTSECI.ttf
# /home/jack/.fonts/LABTSECS.ttf
# /home/jack/.fonts/LABTSECW.ttf
# /home/jack/.fonts/LABTSEC_.ttf
# /home/jack/.fonts/LittleLordFontleroyNF.ttf
# /home/jack/.fonts/Livingst.ttf
# /home/jack/.fonts/LuckiestGuy.ttf
# /home/jack/.fonts/Mademoiselle Camille L.ttf
# /home/jack/.fonts/Mademoiselle Camille.ttf
# /home/jack/.fonts/MicroExtendFLF-Bold.ttf
# /home/jack/.fonts/MicroExtendFLF-BoldItalic.ttf
# /home/jack/.fonts/MicroExtendFLF-Italic.ttf
# /home/jack/.fonts/MicroExtendFLF.ttf
# /home/jack/.fonts/Mindmonkey.ttf
# /home/jack/.fonts/MontereyFLF-Bold.ttf
# /home/jack/.fonts/MontereyFLF-BoldItalic.ttf
# /home/jack/.fonts/MontereyFLF-Italic.ttf
# /home/jack/.fonts/MontereyFLF.ttf
# /home/jack/.fonts/MontereyMediumFLF.ttf
# /home/jack/.fonts/Morcrepito.ttf
# /home/jack/.fonts/MorrisRoman-Black.ttf
# /home/jack/.fonts/MorrisRomanAlternate-Black.ttf
# /home/jack/.fonts/MouldedSaji.ttf
# /home/jack/.fonts/NEWYORK.ttf
# /home/jack/.fonts/News of the World italic.ttf
# /home/jack/.fonts/News of the World regular.ttf
# /home/jack/.fonts/News of the World wide italic.ttf
# /home/jack/.fonts/News of the World wide.ttf
# /home/jack/.fonts/Nightbird.ttf
# /home/jack/.fonts/Nightmare Before Christmas.ttf
# /home/jack/.fonts/No_License_Ghang.ttf
# /home/jack/.fonts/No_License_Ghang_Plain.ttf
# /home/jack/.fonts/Nothing To Lose.ttf
# /home/jack/.fonts/Oh No.ttf
# /home/jack/.fonts/OldGateLaneNF.ttf
# /home/jack/.fonts/One_dance.ttf
# /home/jack/.fonts/Orbitron-Black.ttf
# /home/jack/.fonts/Orbitron-Bold.ttf
# /home/jack/.fonts/Orbitron-Medium.ttf
# /home/jack/.fonts/Orbitron-Regular.ttf
# /home/jack/.fonts/Outlander Bold Italic.ttf
# /home/jack/.fonts/Outlander Italic.ttf
# /home/jack/.fonts/Paganini Light.ttf
# /home/jack/.fonts/Paganini Narrow .ttf
# /home/jack/.fonts/Paganini SemiBold.ttf
# /home/jack/.fonts/Portabell.ttf
# /home/jack/.fonts/Prototype.ttf
# /home/jack/.fonts/Punktype.ttf
# /home/jack/.fonts/Pyrite Crypt.ttf
# /home/jack/.fonts/QuinchoScript_PersonalUse.ttf
# /home/jack/.fonts/ROBOTECH GP.ttf
# /home/jack/.fonts/ROSETAT TRIAL___.ttf
# /home/jack/.fonts/Revorioum PERSONAL use.ttf
# /home/jack/.fonts/RightBankFLF.ttf
# /home/jack/.fonts/Righteous-Regular.ttf
# /home/jack/.fonts/RitzFLF-Italic.ttf
# /home/jack/.fonts/RitzFLF.ttf
# /home/jack/.fonts/RitzFLFCond.ttf
# /home/jack/.fonts/Romantiques.ttf
# /home/jack/.fonts/Rudelsberg Alternate.ttf
# /home/jack/.fonts/Rudelsberg-Initialen.ttf
# /home/jack/.fonts/Rudelsberg-Plakatschrift.ttf
# /home/jack/.fonts/Rudelsberg-Schmuck.ttf
# /home/jack/.fonts/Rudelsberg-Titel.ttf
# /home/jack/.fonts/Rudelsberg.ttf
# /home/jack/.fonts/SF Gushing Meadow SC.ttf
# /home/jack/.fonts/SF Gushing Meadow.ttf
# /home/jack/.fonts/Salterio.ttf
# /home/jack/.fonts/Sareeka-demo.ttf
# /home/jack/.fonts/ScrapItUp.ttf
# /home/jack/.fonts/Shoguns Clan.ttf
# /home/jack/.fonts/Signarita Zhai Rhianne.ttf
# /home/jack/.fonts/Sixth Sense.ttf
# /home/jack/.fonts/Sketch Gothic School.ttf
# /home/jack/.fonts/SonOfTmU.ttf
# /home/jack/.fonts/SouthernAire_Personal_Use_Only.ttf
# /home/jack/.fonts/Strawobbly.ttf
# /home/jack/.fonts/Subway Black.ttf
# /home/jack/.fonts/Subway Shadow.ttf
# /home/jack/.fonts/Susanne Nouveau.ttf
# /home/jack/.fonts/THE CURIOUS INCIDENT.ttf
# /home/jack/.fonts/The Butcher Factory.ttf
# /home/jack/.fonts/The Ring.ttf
# /home/jack/.fonts/TheUnknown-Regular.ttf
# /home/jack/.fonts/Thinking_of_Betty.ttf
# /home/jack/.fonts/This Night.ttf
# /home/jack/.fonts/Timeline.ttf
# /home/jack/.fonts/Tobago Poster Alternate.ttf
# /home/jack/.fonts/Tobago Poster Shadow.ttf
# /home/jack/.fonts/Tobago Poster.ttf
# /home/jack/.fonts/VTKS ROCK GARAGE BAND.ttf
# /home/jack/.fonts/VertigoFLF-Bold.ttf
# /home/jack/.fonts/VertigoFLF.ttf
# /home/jack/.fonts/VertigoPlusFLF-Bold.ttf
# /home/jack/.fonts/VertigoPlusFLF.ttf
# /home/jack/.fonts/Vtks Mercearia.ttf
# /home/jack/.fonts/Vtks Revolt.ttf
# /home/jack/.fonts/Vtks Sonho.ttf
# /home/jack/.fonts/Westmeath Italic.ttf
# /home/jack/.fonts/Westmeath.ttf
# /home/jack/.fonts/Wolf in the City Light.ttf
# /home/jack/.fonts/Wolf in the City.ttf
# /home/jack/.fonts/Young & Beautiful.ttf
# /home/jack/.fonts/Zombie Slayer.ttf
# /home/jack/.fonts/air_mitalic.ttf
# /home/jack/.fonts/airmill_o.ttf
# /home/jack/.fonts/bendable.ttf
# /home/jack/.fonts/berylium bd it.ttf
# /home/jack/.fonts/berylium bd.ttf
# /home/jack/.fonts/berylium rg it.ttf
# /home/jack/.fonts/berylium rg.ttf
# /home/jack/.fonts/beyond_the_mountains.ttf
# /home/jack/.fonts/bloodcrow.ttf
# /home/jack/.fonts/bloodcrowc.ttf
# /home/jack/.fonts/bloodcrowci.ttf
# /home/jack/.fonts/bloodcrowe.ttf
# /home/jack/.fonts/bloodcrowei.ttf
# /home/jack/.fonts/bloodcrowi.ttf
# /home/jack/.fonts/bloodcrowl.ttf
# /home/jack/.fonts/bloodcrows.ttf
# /home/jack/.fonts/bloodcrowsc.ttf
# /home/jack/.fonts/bloodcrowsci.ttf
# /home/jack/.fonts/bloodcrowsi.ttf
# /home/jack/.fonts/bloodlust.ttf
# /home/jack/.fonts/bloodlust3d.ttf
# /home/jack/.fonts/bloodlust3dital.ttf
# /home/jack/.fonts/bloodlustacad.ttf
# /home/jack/.fonts/bloodlustacadital.ttf
# /home/jack/.fonts/bloodlustcond.ttf
# /home/jack/.fonts/bloodlustcondital.ttf
# /home/jack/.fonts/bloodlustexpand.ttf
# /home/jack/.fonts/bloodlustexpandital.ttf
# /home/jack/.fonts/bloodlustgrad.ttf
# /home/jack/.fonts/bloodlustgradital.ttf
# /home/jack/.fonts/bloodlustital.ttf
# /home/jack/.fonts/bloodlustleft.ttf
# /home/jack/.fonts/bloodlustout.ttf
# /home/jack/.fonts/bloodlustoutital.ttf
# /home/jack/.fonts/bloodlustrotal.ttf
# /home/jack/.fonts/boArust.ttf
# /home/jack/.fonts/dark roast.ttf
# /home/jack/.fonts/dontmix.ttf
# /home/jack/.fonts/emily_the_brush.ttf
# /home/jack/.fonts/f'donkulous.ttf
# /home/jack/.fonts/federalescort.ttf
# /home/jack/.fonts/federalescort3d.ttf
# /home/jack/.fonts/federalescort3dital.ttf
# /home/jack/.fonts/federalescortbullet.ttf
# /home/jack/.fonts/federalescortbulletital.ttf
# /home/jack/.fonts/federalescortchrome.ttf
# /home/jack/.fonts/federalescortchromeital.ttf
# /home/jack/.fonts/federalescortcond.ttf
# /home/jack/.fonts/federalescortcondital.ttf
# /home/jack/.fonts/federalescortexpand.ttf
# /home/jack/.fonts/federalescortexpandital.ttf
# /home/jack/.fonts/federalescorthalf.ttf
# /home/jack/.fonts/federalescorthalfital.ttf
# /home/jack/.fonts/federalescortital.ttf
# /home/jack/.fonts/federalescortlaser.ttf
# /home/jack/.fonts/federalescortlaserital.ttf
# /home/jack/.fonts/federalescortleft.ttf
# /home/jack/.fonts/federalescortout.ttf
# /home/jack/.fonts/federalescortoutital.ttf
# /home/jack/.fonts/federalescortscan.ttf
# /home/jack/.fonts/federalescortscanital.ttf
# /home/jack/.fonts/federalescortsemiital.ttf
# /home/jack/.fonts/folkard_.ttf
# /home/jack/.fonts/footfight.ttf
# /home/jack/.fonts/gang_wolfik.ttf
# /home/jack/.fonts/german____underground.ttf
# /home/jack/.fonts/heav.ttf
# /home/jack/.fonts/iforces.ttf
# /home/jack/.fonts/nightchilde.ttf
# /home/jack/.fonts/nightchilde3d.ttf
# /home/jack/.fonts/nightchilde3dital.ttf
# /home/jack/.fonts/nightchildecond.ttf
# /home/jack/.fonts/nightchildecondital.ttf
# /home/jack/.fonts/nightchildeexpand.ttf
# /home/jack/.fonts/nightchildeexpandital.ttf
# /home/jack/.fonts/nightchildeital.ttf
# /home/jack/.fonts/nightchildeleft.ttf
# /home/jack/.fonts/nightchilderotal.ttf
# /home/jack/.fonts/nightchilderotate.ttf
# /home/jack/.fonts/nightchildestag.ttf
# /home/jack/.fonts/nightchildestagital.ttf
# /home/jack/.fonts/outlander.ttf
# /home/jack/.fonts/pe______.ttf
# /home/jack/.fonts/rawhide_raw_2012.ttf
# /home/jack/.fonts/rothenbg.ttf
# /home/jack/.fonts/satan_hum_sav.ttf
# /home/jack/.fonts/staravenue.ttf
# /home/jack/.fonts/trashco.ttf
# /home/jack/.fonts/underworld.ttf
# /home/jack/.fonts/valdemar.ttf
# /home/jack/.fonts/vtks Rascunho  Errado.ttf
# /home/jack/.fonts/Font2/Gypsy Curse.ttf
# /home/jack/.fonts/GotHeroin/Got_Heroin.ttf
# /home/jack/.fonts/Living Hell/Living Hell.ttf
# /home/jack/.fonts/__MACOSX/._NEWYORK.ttf
# /home/jack/.julia/v0.5/ForwardDiff/docs/_static/fonts/Inconsolata-Bold.ttf
# /home/jack/.julia/v0.5/ForwardDiff/docs/_static/fonts/Inconsolata-Regular.ttf
# /home/jack/.julia/v0.5/ForwardDiff/docs/_static/fonts/Lato-Bold.ttf
# /home/jack/.julia/v0.5/ForwardDiff/docs/_static/fonts/Lato-Regular.ttf
# /home/jack/.julia/v0.5/ForwardDiff/docs/_static/fonts/RobotoSlab-Bold.ttf
# /home/jack/.julia/v0.5/ForwardDiff/docs/_static/fonts/RobotoSlab-Regular.ttf
# /home/jack/.julia/v0.5/ForwardDiff/docs/_static/fonts/fontawesome-webfont.ttf
# /home/jack/.meteor/packages/ecmascript/.0.8.0.y01uxl++os+web.browser+web.cordova/plugin.compile-ecmascript.os/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/aller-bold.ttf
# /home/jack/.meteor/packages/ecmascript/.0.8.0.y01uxl++os+web.browser+web.cordova/plugin.compile-ecmascript.os/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/aller-light.ttf
# /home/jack/.meteor/packages/ecmascript/.0.8.0.y01uxl++os+web.browser+web.cordova/plugin.compile-ecmascript.os/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/roboto-black.ttf
# /home/jack/.meteor/packages/less/.2.7.9.1d9nobq++os+web.browser+web.cordova/plugin.compileLessBatch.os/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/aller-bold.ttf
# /home/jack/.meteor/packages/less/.2.7.9.1d9nobq++os+web.browser+web.cordova/plugin.compileLessBatch.os/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/aller-light.ttf
# /home/jack/.meteor/packages/less/.2.7.9.1d9nobq++os+web.browser+web.cordova/plugin.compileLessBatch.os/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/roboto-black.ttf
# /home/jack/.meteor/packages/meteor-tool/.1.5.0.utbu0o++os.linux.x86_64+web.browser+web.cordova/mt-os.linux.x86_64/isopackets/constraint-solver/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/aller-bold.ttf
# /home/jack/.meteor/packages/meteor-tool/.1.5.0.utbu0o++os.linux.x86_64+web.browser+web.cordova/mt-os.linux.x86_64/isopackets/constraint-solver/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/aller-light.ttf
# /home/jack/.meteor/packages/meteor-tool/.1.5.0.utbu0o++os.linux.x86_64+web.browser+web.cordova/mt-os.linux.x86_64/isopackets/constraint-solver/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/roboto-black.ttf
# /home/jack/.meteor/packages/meteor-tool/.1.5.0.utbu0o++os.linux.x86_64+web.browser+web.cordova/mt-os.linux.x86_64/isopackets/cordova-support/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/aller-bold.ttf
# /home/jack/.meteor/packages/meteor-tool/.1.5.0.utbu0o++os.linux.x86_64+web.browser+web.cordova/mt-os.linux.x86_64/isopackets/cordova-support/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/aller-light.ttf
# /home/jack/.meteor/packages/meteor-tool/.1.5.0.utbu0o++os.linux.x86_64+web.browser+web.cordova/mt-os.linux.x86_64/isopackets/cordova-support/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/roboto-black.ttf
# /home/jack/.meteor/packages/meteor-tool/.1.5.0.utbu0o++os.linux.x86_64+web.browser+web.cordova/mt-os.linux.x86_64/isopackets/ddp/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/aller-bold.ttf
# /home/jack/.meteor/packages/meteor-tool/.1.5.0.utbu0o++os.linux.x86_64+web.browser+web.cordova/mt-os.linux.x86_64/isopackets/ddp/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/aller-light.ttf
# /home/jack/.meteor/packages/meteor-tool/.1.5.0.utbu0o++os.linux.x86_64+web.browser+web.cordova/mt-os.linux.x86_64/isopackets/ddp/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/roboto-black.ttf
# /home/jack/.meteor/packages/meteor-tool/.1.5.0.utbu0o++os.linux.x86_64+web.browser+web.cordova/mt-os.linux.x86_64/isopackets/logging/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/aller-bold.ttf
# /home/jack/.meteor/packages/meteor-tool/.1.5.0.utbu0o++os.linux.x86_64+web.browser+web.cordova/mt-os.linux.x86_64/isopackets/logging/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/aller-light.ttf
# /home/jack/.meteor/packages/meteor-tool/.1.5.0.utbu0o++os.linux.x86_64+web.browser+web.cordova/mt-os.linux.x86_64/isopackets/logging/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/roboto-black.ttf
# /home/jack/.meteor/packages/meteortoys_toykit/.3.0.4.16sj0sr++os+web.browser+web.cordova/web.browser/packages/meteortoys_toykit/public/LiberationMono-Bold.ttf
# /home/jack/.meteor/packages/meteortoys_toykit/.3.0.4.16sj0sr++os+web.browser+web.cordova/web.browser/packages/meteortoys_toykit/public/LiberationMono-Regular.ttf
# /home/jack/.meteor/packages/meteortoys_toykit/.3.0.4.16sj0sr++os+web.browser+web.cordova/web.cordova/packages/meteortoys_toykit/public/LiberationMono-Bold.ttf
# /home/jack/.meteor/packages/meteortoys_toykit/.3.0.4.16sj0sr++os+web.browser+web.cordova/web.cordova/packages/meteortoys_toykit/public/LiberationMono-Regular.ttf
# /home/jack/.meteor/packages/modules-runtime/.0.8.0.gkjl8b++os+web.browser+web.cordova/npm/node_modules/install/docs/public/fonts/aller-bold.ttf
# /home/jack/.meteor/packages/modules-runtime/.0.8.0.gkjl8b++os+web.browser+web.cordova/npm/node_modules/install/docs/public/fonts/aller-light.ttf
# /home/jack/.meteor/packages/modules-runtime/.0.8.0.gkjl8b++os+web.browser+web.cordova/npm/node_modules/install/docs/public/fonts/roboto-black.ttf
# /home/jack/.meteor/packages/standard-minifier-js/.2.1.0.nt2b9c++os+web.browser+web.cordova/plugin.minifyStdJS.os/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/aller-bold.ttf
# /home/jack/.meteor/packages/standard-minifier-js/.2.1.0.nt2b9c++os+web.browser+web.cordova/plugin.minifyStdJS.os/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/aller-light.ttf
# /home/jack/.meteor/packages/standard-minifier-js/.2.1.0.nt2b9c++os+web.browser+web.cordova/plugin.minifyStdJS.os/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/roboto-black.ttf
# /home/jack/.meteor/packages/stylus/.2.513.9.1sz3g42++os+web.browser+web.cordova/plugin.compileStylusBatch.os/npm/node_modules/meteor/compileStylusBatch/node_modules/nib/iconic/iconic_stroke.ttf
# /home/jack/.meteor/packages/stylus/.2.513.9.1sz3g42++os+web.browser+web.cordova/plugin.compileStylusBatch.os/npm/node_modules/meteor/compileStylusBatch/node_modules/stylus/graphics/Vectors/stylus.ttf
# /home/jack/.meteor/packages/stylus/.2.513.9.1sz3g42++os+web.browser+web.cordova/plugin.compileStylusBatch.os/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/aller-bold.ttf
# /home/jack/.meteor/packages/stylus/.2.513.9.1sz3g42++os+web.browser+web.cordova/plugin.compileStylusBatch.os/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/aller-light.ttf
# /home/jack/.meteor/packages/stylus/.2.513.9.1sz3g42++os+web.browser+web.cordova/plugin.compileStylusBatch.os/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/roboto-black.ttf
# /home/jack/.meteor/packages/templating-compiler/.1.3.2.7ie2fk++os+web.browser+web.cordova/plugin.compileTemplatesBatch.os/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/aller-bold.ttf
# /home/jack/.meteor/packages/templating-compiler/.1.3.2.7ie2fk++os+web.browser+web.cordova/plugin.compileTemplatesBatch.os/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/aller-light.ttf
# /home/jack/.meteor/packages/templating-compiler/.1.3.2.7ie2fk++os+web.browser+web.cordova/plugin.compileTemplatesBatch.os/npm/node_modules/meteor/modules-runtime/node_modules/install/docs/public/fonts/roboto-black.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/AndroidClock.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/AndroidClock_Highlight.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/AndroidClock_Solid.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/CarroisGothicSC-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/Clockopia.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/ComingSoon.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/CutiveMono.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/DancingScript-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/DancingScript-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/DroidSans-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/DroidSans.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/DroidSansFallback.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/DroidSansMono.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NanumGothic.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoColorEmoji.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoNaskhArabic-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoNaskhArabic-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoNaskhArabicUI-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoNaskhArabicUI-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansArmenian-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansArmenian-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansBalinese-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansBamum-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansBatak-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansBengali-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansBengali-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansBengaliUI-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansBengaliUI-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansBuginese-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansBuhid-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansCanadianAboriginal-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansCham-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansCham-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansCherokee-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansCoptic-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansDevanagari-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansDevanagari-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansDevanagariUI-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansDevanagariUI-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansEthiopic-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansEthiopic-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansGeorgian-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansGeorgian-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansGlagolitic-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansGujarati-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansGujarati-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansGujaratiUI-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansGujaratiUI-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansGurmukhi-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansGurmukhi-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansGurmukhiUI-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansGurmukhiUI-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansHanunoo-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansHebrew-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansHebrew-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansJavanese-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansKannada-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansKannada-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansKannadaUI-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansKannadaUI-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansKayahLi-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansKhmer-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansKhmer-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansKhmerUI-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansKhmerUI-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansLao-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansLao-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansLaoUI-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansLaoUI-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansLepcha-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansLimbu-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansLisu-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansMalayalam-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansMalayalam-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansMalayalamUI-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansMalayalamUI-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansMandaic-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansMeeteiMayek-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansMongolian-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansMyanmar-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansMyanmar-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansMyanmarUI-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansMyanmarUI-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansNKo-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansNewTaiLue-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansOlChiki-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansOriya-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansOriya-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansOriyaUI-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansOriyaUI-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansRejang-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansSaurashtra-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansSinhala-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansSinhala-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansSundanese-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansSylotiNagri-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansSymbols-Regular-Subsetted.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansSyriacEstrangela-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansTagbanwa-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansTaiLe-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansTaiTham-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansTaiViet-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansTamil-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansTamil-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansTamilUI-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansTamilUI-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansTelugu-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansTelugu-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansTeluguUI-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansTeluguUI-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansThaana-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansThaana-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansThai-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansThai-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansThaiUI-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansThaiUI-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansTibetan-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansTifinagh-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansVai-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSansYi-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSerif-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSerif-BoldItalic.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSerif-Italic.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/NotoSerif-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/Roboto-Black.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/Roboto-BlackItalic.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/Roboto-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/Roboto-BoldItalic.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/Roboto-Italic.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/Roboto-Light.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/Roboto-LightItalic.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/Roboto-Medium.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/Roboto-MediumItalic.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/Roboto-Regular.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/Roboto-Thin.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/Roboto-ThinItalic.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/RobotoCondensed-Bold.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/RobotoCondensed-BoldItalic.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/RobotoCondensed-Italic.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/RobotoCondensed-Light.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/RobotoCondensed-LightItalic.ttf
# /home/jack/Android/Sdk/platforms/android-23/data/fonts/RobotoCondensed-Regular.ttf
# /home/jack/AngularJS/Redis_GUI/rdm/src/resources/fonts/OpenSans-Bold.ttf
# /home/jack/AngularJS/Redis_GUI/rdm/src/resources/fonts/OpenSans-BoldItalic.ttf
# /home/jack/AngularJS/Redis_GUI/rdm/src/resources/fonts/OpenSans-ExtraBold.ttf
# /home/jack/AngularJS/Redis_GUI/rdm/src/resources/fonts/OpenSans-ExtraBoldItalic.ttf
# /home/jack/AngularJS/Redis_GUI/rdm/src/resources/fonts/OpenSans-Italic.ttf
# /home/jack/AngularJS/Redis_GUI/rdm/src/resources/fonts/OpenSans-Light.ttf
# /home/jack/AngularJS/Redis_GUI/rdm/src/resources/fonts/OpenSans-LightItalic.ttf
# /home/jack/AngularJS/Redis_GUI/rdm/src/resources/fonts/OpenSans-Regular.ttf
# /home/jack/AngularJS/Redis_GUI/rdm/src/resources/fonts/OpenSans-Semibold.ttf
# /home/jack/AngularJS/Redis_GUI/rdm/src/resources/fonts/OpenSans-SemiboldItalic.ttf
# /home/jack/AngularJS/barebones-Boot-Strap/startbootstrap-bare/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/barebones-Boot-Strap/startbootstrap-bare/meanBootStrap/.bower-cache/478ab1d28ba78f550601bf536eea62f5/3.3.6/dist/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/barebones-Boot-Strap/startbootstrap-bare/meanBootStrap/.bower-cache/478ab1d28ba78f550601bf536eea62f5/3.3.6/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/barebones-Boot-Strap/startbootstrap-bare/meanBootStrap/bower_components/bootstrap/dist/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/barebones-Boot-Strap/startbootstrap-bare/meanBootStrap/bower_components/bootstrap/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/barebones-Boot-Strap/startbootstrap-bare/meanBootStrap/node_modules/bootstrap/dist/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/barebones-Boot-Strap/startbootstrap-bare/meanBootStrap/node_modules/bootstrap/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/barebones-Boot-Strap/startbootstrap-bare/meanBootStrap/node_modules/selenium-webdriver/lib/test/data/js/skins/lightgray/fonts/tinymce-small.ttf
# /home/jack/AngularJS/barebones-Boot-Strap/startbootstrap-bare/meanBootStrap/node_modules/selenium-webdriver/lib/test/data/js/skins/lightgray/fonts/tinymce.ttf
# /home/jack/AngularJS/barebones-Boot-Strap/startbootstrap-bare/meanBootStrap/packages/custom/meanBootStrap/public/assets/fonts/mark_simonson_-_proxima_nova_regular.ttf
# /home/jack/AngularJS/barebones-Boot-Strap/startbootstrap-bare/meanBootStrap/packages/custom/meanBootStrap/public/assets/fonts/opensanshebrew-light.ttf
# /home/jack/AngularJS/barebones-Boot-Strap/startbootstrap-bare/meanBootStrap/packages/custom/meanBootStrap/public/assets/fonts/opensanshebrew-regular.ttf
# /home/jack/AngularJS/barebones-Boot-Strap/startbootstrap-bare/meanBootStrap/packages/custom/meanBootStrap/public/assets/fonts/proximanova-light.ttf
# /home/jack/AngularJS/barebones-Boot-Strap/startbootstrap-bare/meanBootStrap/packages/custom/meanBootStrap/public/assets/fonts/ufonts.com_futura-book.ttf
# /home/jack/AngularJS/bootstrap-3.3.6/dist/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/bootstrap-3.3.6/docs/dist/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/bootstrap-3.3.6/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/linnovate/LinnApp/.bower-cache/478ab1d28ba78f550601bf536eea62f5/3.3.6/dist/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/linnovate/LinnApp/.bower-cache/478ab1d28ba78f550601bf536eea62f5/3.3.6/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/linnovate/LinnApp/bower_components/bootstrap/dist/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/linnovate/LinnApp/bower_components/bootstrap/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/linnovate/LinnApp/node_modules/bootstrap/dist/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/linnovate/LinnApp/node_modules/bootstrap/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/linnovate/LinnApp/node_modules/selenium-webdriver/lib/test/data/js/skins/lightgray/fonts/tinymce-small.ttf
# /home/jack/AngularJS/linnovate/LinnApp/node_modules/selenium-webdriver/lib/test/data/js/skins/lightgray/fonts/tinymce.ttf
# /home/jack/AngularJS/linnovate/mean/.bower-cache/478ab1d28ba78f550601bf536eea62f5/3.3.6/dist/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/linnovate/mean/.bower-cache/478ab1d28ba78f550601bf536eea62f5/3.3.6/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/linnovate/mean/bower_components/bootstrap/dist/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/linnovate/mean/bower_components/bootstrap/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/linnovate/mean/node_modules/bootstrap/dist/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/linnovate/mean/node_modules/bootstrap/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/linnovate/mean/node_modules/selenium-webdriver/lib/test/data/js/skins/lightgray/fonts/tinymce-small.ttf
# /home/jack/AngularJS/linnovate/mean/node_modules/selenium-webdriver/lib/test/data/js/skins/lightgray/fonts/tinymce.ttf
# /home/jack/AngularJS/makeApp/makeApp/platforms/android/assets/www/lib/ionic/fonts/ionicons.ttf
# /home/jack/AngularJS/makeApp/makeApp/platforms/android/build/intermediates/assets/debug/www/lib/ionic/fonts/ionicons.ttf
# /home/jack/AngularJS/makeApp/makeApp/www/lib/ionic/fonts/ionicons.ttf
# /home/jack/AngularJS/use-quacker/Quaker-Bak-working-GOOD/Quacker/public/fonts/glyphicons/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/use-quacker/Quaker-Bak-working-GOOD/SSL-Quack/Quacker/public/fonts/glyphicons/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/use-quacker/wed-thirteen-july/Quaker-Bak-working-GOOD/GOOD_QACK_BACK/Quacker/public/fonts/glyphicons/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS/use-quacker/wed-thirteen-july/Quaker-Bak-working-GOOD/Quacker/public/fonts/glyphicons/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS-Modules/angular-1.5.7/docs/components/bootstrap-3.1.1/fonts/glyphicons-halflings-regular.ttf
# /home/jack/AngularJS-Modules/angular-1.5.7/docs/components/open-sans-fontface-1.0.4/fonts/Bold/OpenSans-Bold.ttf
# /home/jack/AngularJS-Modules/angular-1.5.7/docs/components/open-sans-fontface-1.0.4/fonts/BoldItalic/OpenSans-BoldItalic.ttf
# /home/jack/AngularJS-Modules/angular-1.5.7/docs/components/open-sans-fontface-1.0.4/fonts/ExtraBold/OpenSans-ExtraBold.ttf
# /home/jack/AngularJS-Modules/angular-1.5.7/docs/components/open-sans-fontface-1.0.4/fonts/ExtraBoldItalic/OpenSans-ExtraBoldItalic.ttf
# /home/jack/AngularJS-Modules/angular-1.5.7/docs/components/open-sans-fontface-1.0.4/fonts/Italic/OpenSans-Italic.ttf
# /home/jack/AngularJS-Modules/angular-1.5.7/docs/components/open-sans-fontface-1.0.4/fonts/Light/OpenSans-Light.ttf
# /home/jack/AngularJS-Modules/angular-1.5.7/docs/components/open-sans-fontface-1.0.4/fonts/LightItalic/OpenSans-LightItalic.ttf
# /home/jack/AngularJS-Modules/angular-1.5.7/docs/components/open-sans-fontface-1.0.4/fonts/Regular/OpenSans-Regular.ttf
# /home/jack/AngularJS-Modules/angular-1.5.7/docs/components/open-sans-fontface-1.0.4/fonts/Semibold/OpenSans-Semibold.ttf
# /home/jack/AngularJS-Modules/angular-1.5.7/docs/components/open-sans-fontface-1.0.4/fonts/SemiboldItalic/OpenSans-SemiboldItalic.ttf
# /home/jack/Desktop/C++STUFF/CImg/html/cimgmenu/MG_Icons.ttf
# /home/jack/Desktop/C++STUFF/CImg/html/cimgmenu/Ubuntu-webfont.ttf
# /home/jack/Desktop/ChatterBot/build/_static/fonts/Inconsolata-Bold.ttf
# /home/jack/Desktop/ChatterBot/build/_static/fonts/Inconsolata-Regular.ttf
# /home/jack/Desktop/ChatterBot/build/_static/fonts/Lato-Bold.ttf
# /home/jack/Desktop/ChatterBot/build/_static/fonts/Lato-Regular.ttf
# /home/jack/Desktop/ChatterBot/build/_static/fonts/RobotoSlab-Bold.ttf
# /home/jack/Desktop/ChatterBot/build/_static/fonts/RobotoSlab-Regular.ttf
# /home/jack/Desktop/ChatterBot/build/_static/fonts/fontawesome-webfont.ttf
# /home/jack/Desktop/GoStuff/awesome-go/tmpl/assets/fonts/firasans.ttf
# /home/jack/Desktop/GoStuff/awesome-go/tmpl/assets/fonts/firasansbold.ttf
# /home/jack/Desktop/GoStuff/awesome-go/tmpl/assets/fonts/firasansbolditalic.ttf
# /home/jack/Desktop/GoStuff/awesome-go/tmpl/assets/fonts/firasansbook.ttf
# /home/jack/Desktop/GoStuff/awesome-go/tmpl/assets/fonts/firasansbookitalic.ttf
# /home/jack/Desktop/GoStuff/awesome-go/tmpl/assets/fonts/firasansextralight.ttf
# /home/jack/Desktop/GoStuff/awesome-go/tmpl/assets/fonts/firasansextralightitalic.ttf
# /home/jack/Desktop/GoStuff/awesome-go/tmpl/assets/fonts/firasansitalic.ttf
# /home/jack/Desktop/GoStuff/awesome-go/tmpl/assets/fonts/firasanslight.ttf
# /home/jack/Desktop/GoStuff/awesome-go/tmpl/assets/fonts/firasanslightitalic.ttf
# /home/jack/Desktop/GoStuff/awesome-go/tmpl/assets/fonts/firasansmedium.ttf
# /home/jack/Desktop/GoStuff/awesome-go/tmpl/assets/fonts/firasansmediumitalic.ttf
# /home/jack/Desktop/GoStuff/awesome-go/tmpl/assets/fonts/firasanssemibold.ttf
# /home/jack/Desktop/GoStuff/awesome-go/tmpl/assets/fonts/firasanssemibolditalic.ttf
# /home/jack/Desktop/IPyLua/LuaAV/LuaAV/extra/resources/fonts/VeraMoBI.ttf
# /home/jack/Desktop/IPyLua/LuaAV/LuaAV/extra/resources/fonts/VeraMoBd.ttf
# /home/jack/Desktop/IPyLua/LuaAV/LuaAV/extra/resources/fonts/VeraMoIt.ttf
# /home/jack/Desktop/IPyLua/LuaAV/LuaAV/extra/resources/fonts/VeraMono.ttf
# /home/jack/Desktop/QuickBasic/cyberbit.ttf
# /home/jack/Desktop/Ruby/Example-Sketches/samples/external_library/java_processing/geomerative/data/FreeSans.ttf
# /home/jack/Desktop/Ruby/Example-Sketches/samples/processing_app/topics/advanced_data/data/Georgia.ttf
# /home/jack/Desktop/Ruby/Example-Sketches/samples/processing_app/topics/advanced_data/data/Merriweather-Light.ttf
# /home/jack/Desktop/ai-chatbot-framework/app/static/commons/fonts/glyphicons-halflings-regular.ttf
# /home/jack/Desktop/deep-dream-generator/LOCAL-notebooks/Humor-Sans.ttf
# /home/jack/Desktop/deep-dream-generator/julia-f4c6c9d4bb/share/doc/julia/html/_static/fonts/fontawesome-webfont.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/EaselJS/tutorials/Fonts/assets/Dorsa-Regular.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/P5.JS_MyExamples/sites/p5js.org/workingExamples/Integrating-sound/p5.js-sound-master/docs/css/f/AvenirNextLTW01-Medium.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/P5.JS_MyExamples/sites/p5js.org/workingExamples/Integrating-sound/p5.js-sound-master/docs/css/f/inconsolata.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/P5.JS_MyExamples/sites/p5js.org/workingExamples/css/fonts/AvenirNextLTW01-Medium.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/P5.JS_MyExamples/sites/p5js.org/workingExamples/css/fonts/inconsolata.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/P5.JS_MyExamples/stress/Jack/tinymce/skins/lightgray/fonts/tinymce-small.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/P5.JS_MyExamples/stress/Jack/tinymce/skins/lightgray/fonts/tinymce.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/p5.js/docs/yuidoc-p5-theme/assets/Bold.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/p5.js/docs/yuidoc-p5-theme/assets/Italic.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/p5.js/test/manual-test-examples/async/loadFont/global/acmesa.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/p5.js/test/manual-test-examples/async/loadFont/instance/acmesa.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/p5.js/test/manual-test-examples/p5.Font/Inconsolata-Bold.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/p5.js/test/manual-test-examples/p5.Font/Lato-Black.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/p5.js/test/manual-test-examples/p5.Font/Merriweather-LightItalic.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/p5.js/test/manual-test-examples/p5.Font/Montserrat-Regular.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/p5.js/test/manual-test-examples/p5.Font/OpenSans-Regular.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/p5.js/test/manual-test-examples/p5.Font/PlayfairDisplay-Regular.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/p5.js/test/manual-test-examples/p5.Font/SourceSansPro-Bold.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/p5.js/test/manual-test-examples/p5.Font/SourceSansPro-Italic.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/p5.js/test/manual-test-examples/p5.Font/acmesa.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/p5.js/test/unit/assets/acmesa.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/fonts/AnonymousPro-Bold.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/fonts/AnonymousPro-Regular.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/fonts/Carlito-Bold.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/fonts/Carlito-Regular.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/fonts/LucidaBrightDemiBold.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/fonts/LucidaBrightDemiItalic.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/fonts/LucidaBrightItalic.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/fonts/LucidaBrightRegular.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/fonts/LucidaSansDemiBold.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/fonts/LucidaSansRegular.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/fonts/LucidaTypewriterBold.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/fonts/LucidaTypewriterRegular.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/fonts/SourceCodePro-Bold.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/fonts/SourceCodePro-Regular.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/fonts/SourceSansPro-Regular.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/fonts/SourceSansPro-Semibold.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/oblique-fonts/LucidaSansDemiOblique.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/oblique-fonts/LucidaSansOblique.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/oblique-fonts/LucidaTypewriterBoldOblique.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/java/lib/oblique-fonts/LucidaTypewriterOblique.ttf
# /home/jack/Desktop/deep-dream-generator/notebooks/JavaScript/ThreeJS.jl/processing-3.2.1/modes/java/examples/Basics/Data/CharactersStrings/data/SourceCodePro-Regular.ttf
# ...
# /usr/share/fonts/truetype/noto/NotoSansTamilUI-Regular.ttf
# /usr/share/fonts/truetype/noto/NotoSansTelugu-Bold.ttf
# /usr/share/fonts/truetype/noto/NotoSansTelugu-Regular.ttf
# /usr/share/fonts/truetype/noto/NotoSansTeluguUI-Bold.ttf
# /usr/share/fonts/truetype/noto/NotoSansTeluguUI-Regular.ttf
# /usr/share/fonts/truetype/noto/NotoSansThaana-Bold.ttf
# /usr/share/fonts/truetype/noto/NotoSansThaana-Regular.ttf
# /usr/share/fonts/truetype/noto/NotoSansThai-Bold.ttf
# /usr/share/fonts/truetype/noto/NotoSansThai-Regular.ttf
# /usr/share/fonts/truetype/noto/NotoSansThaiUI-Bold.ttf
# /usr/share/fonts/truetype/noto/NotoSansThaiUI-Regular.ttf
# /usr/share/fonts/truetype/noto/NotoSansTibetan-Bold.ttf
# /usr/share/fonts/truetype/noto/NotoSansTibetan-Regular.ttf
# /usr/share/fonts/truetype/noto/NotoSansUI-Bold.ttf
# /usr/share/fonts/truetype/noto/NotoSansUI-BoldItalic.ttf
# /usr/share/fonts/truetype/noto/NotoSansUI-Italic.ttf
# /usr/share/fonts/truetype/noto/NotoSansUI-Regular.ttf
# /usr/share/fonts/truetype/noto/NotoSerif-Bold.ttf
# /usr/share/fonts/truetype/noto/NotoSerif-BoldItalic.ttf
# /usr/share/fonts/truetype/noto/NotoSerif-Italic.ttf
# /usr/share/fonts/truetype/noto/NotoSerif-Regular.ttf
# /usr/share/fonts/truetype/noto/NotoSerifArmenian-Bold.ttf
# /usr/share/fonts/truetype/noto/NotoSerifArmenian-Regular.ttf
# /usr/share/fonts/truetype/noto/NotoSerifBengali-Bold.ttf
# /usr/share/fonts/truetype/noto/NotoSerifBengali-Regular.ttf
# /usr/share/fonts/truetype/noto/NotoSerifGeorgian-Bold.ttf
# /usr/share/fonts/truetype/noto/NotoSerifGeorgian-Regular.ttf
# /usr/share/fonts/truetype/noto/NotoSerifGujarati-Bold.ttf
# /usr/share/fonts/truetype/noto/NotoSerifGujarati-Regular.ttf
# /usr/share/fonts/truetype/noto/NotoSerifKannada-Bold.ttf
# /usr/share/fonts/truetype/noto/NotoSerifKannada-Regular.ttf
# /usr/share/fonts/truetype/noto/NotoSerifKhmer-Bold.ttf
# /usr/share/fonts/truetype/noto/NotoSerifKhmer-Regular.ttf
# /usr/share/fonts/truetype/noto/NotoSerifLao-Bold.ttf
# /usr/share/fonts/truetype/noto/NotoSerifLao-Regular.ttf
# /usr/share/fonts/truetype/noto/NotoSerifMalayalam-Bold.ttf
# /usr/share/fonts/truetype/noto/NotoSerifMalayalam-Regular.ttf
# /usr/share/fonts/truetype/noto/NotoSerifTamil-Bold.ttf
# /usr/share/fonts/truetype/noto/NotoSerifTamil-Regular.ttf
# /usr/share/fonts/truetype/noto/NotoSerifTelugu-Bold.ttf
# /usr/share/fonts/truetype/noto/NotoSerifTelugu-Regular.ttf
# /usr/share/fonts/truetype/noto/NotoSerifThai-Bold.ttf
# /usr/share/fonts/truetype/noto/NotoSerifThai-Regular.ttf
# /usr/share/fonts/truetype/openoffice/opens___.ttf
# /usr/share/fonts/truetype/padauk/Padauk-bold.ttf
# /usr/share/fonts/truetype/padauk/Padauk-book.ttf
# /usr/share/fonts/truetype/padauk/Padauk-bookbold.ttf
# /usr/share/fonts/truetype/padauk/Padauk.ttf
# /usr/share/fonts/truetype/roboto/hinted/Roboto-Black.ttf
# /usr/share/fonts/truetype/roboto/hinted/Roboto-BlackItalic.ttf
# /usr/share/fonts/truetype/roboto/hinted/Roboto-Bold.ttf
# /usr/share/fonts/truetype/roboto/hinted/Roboto-BoldItalic.ttf
# /usr/share/fonts/truetype/roboto/hinted/Roboto-Italic.ttf
# /usr/share/fonts/truetype/roboto/hinted/Roboto-Light.ttf
# /usr/share/fonts/truetype/roboto/hinted/Roboto-LightItalic.ttf
# /usr/share/fonts/truetype/roboto/hinted/Roboto-Medium.ttf
# /usr/share/fonts/truetype/roboto/hinted/Roboto-MediumItalic.ttf
# /usr/share/fonts/truetype/roboto/hinted/Roboto-Regular.ttf
# /usr/share/fonts/truetype/roboto/hinted/Roboto-Thin.ttf
# /usr/share/fonts/truetype/roboto/hinted/Roboto-ThinItalic.ttf
# /usr/share/fonts/truetype/roboto/hinted/RobotoCondensed-Bold.ttf
# /usr/share/fonts/truetype/roboto/hinted/RobotoCondensed-BoldItalic.ttf
# /usr/share/fonts/truetype/roboto/hinted/RobotoCondensed-Italic.ttf
# /usr/share/fonts/truetype/roboto/hinted/RobotoCondensed-Light.ttf
# /usr/share/fonts/truetype/roboto/hinted/RobotoCondensed-LightItalic.ttf
# /usr/share/fonts/truetype/roboto/hinted/RobotoCondensed-Regular.ttf
# /usr/share/fonts/truetype/runny/RunyTunesRevisitedNF.ttf
# /usr/share/fonts/truetype/sinhala/lklug.ttf
# /usr/share/fonts/truetype/takao-gothic/TakaoPGothic.ttf
# /usr/share/fonts/truetype/tibetan-machine/TibetanMachineUni.ttf
# /usr/share/fonts/truetype/tlwg/Garuda-Bold.ttf
# /usr/share/fonts/truetype/tlwg/Garuda-BoldOblique.ttf
# /usr/share/fonts/truetype/tlwg/Garuda-Oblique.ttf
# /usr/share/fonts/truetype/tlwg/Garuda.ttf
# /usr/share/fonts/truetype/tlwg/Kinnari-Bold.ttf
# /usr/share/fonts/truetype/tlwg/Kinnari-BoldItalic.ttf
# /usr/share/fonts/truetype/tlwg/Kinnari-BoldOblique.ttf
# /usr/share/fonts/truetype/tlwg/Kinnari-Italic.ttf
# /usr/share/fonts/truetype/tlwg/Kinnari-Oblique.ttf
# /usr/share/fonts/truetype/tlwg/Kinnari.ttf
# /usr/share/fonts/truetype/tlwg/Laksaman-Bold.ttf
# /usr/share/fonts/truetype/tlwg/Laksaman-BoldItalic.ttf
# /usr/share/fonts/truetype/tlwg/Laksaman-Italic.ttf
# /usr/share/fonts/truetype/tlwg/Laksaman.ttf
# /usr/share/fonts/truetype/tlwg/Loma-Bold.ttf
# /usr/share/fonts/truetype/tlwg/Loma-BoldOblique.ttf
# /usr/share/fonts/truetype/tlwg/Loma-Oblique.ttf
# /usr/share/fonts/truetype/tlwg/Loma.ttf
# /usr/share/fonts/truetype/tlwg/Norasi-Bold.ttf
# /usr/share/fonts/truetype/tlwg/Norasi-BoldItalic.ttf
# /usr/share/fonts/truetype/tlwg/Norasi-BoldOblique.ttf
# /usr/share/fonts/truetype/tlwg/Norasi-Italic.ttf
# /usr/share/fonts/truetype/tlwg/Norasi-Oblique.ttf
# /usr/share/fonts/truetype/tlwg/Norasi.ttf
# /usr/share/fonts/truetype/tlwg/Purisa-Bold.ttf
# /usr/share/fonts/truetype/tlwg/Purisa-BoldOblique.ttf
# /usr/share/fonts/truetype/tlwg/Purisa-Oblique.ttf
# /usr/share/fonts/truetype/tlwg/Purisa.ttf
# /usr/share/fonts/truetype/tlwg/Sawasdee-Bold.ttf
# /usr/share/fonts/truetype/tlwg/Sawasdee-BoldOblique.ttf
# /usr/share/fonts/truetype/tlwg/Sawasdee-Oblique.ttf
# /usr/share/fonts/truetype/tlwg/Sawasdee.ttf
# /usr/share/fonts/truetype/tlwg/TlwgMono-Bold.ttf
# /usr/share/fonts/truetype/tlwg/TlwgMono-BoldOblique.ttf
# /usr/share/fonts/truetype/tlwg/TlwgMono-Oblique.ttf
# /usr/share/fonts/truetype/tlwg/TlwgMono.ttf
# /usr/share/fonts/truetype/tlwg/TlwgTypewriter-Bold.ttf
# /usr/share/fonts/truetype/tlwg/TlwgTypewriter-BoldOblique.ttf
# /usr/share/fonts/truetype/tlwg/TlwgTypewriter-Oblique.ttf
# /usr/share/fonts/truetype/tlwg/TlwgTypewriter.ttf
# /usr/share/fonts/truetype/tlwg/TlwgTypist-Bold.ttf
# /usr/share/fonts/truetype/tlwg/TlwgTypist-BoldOblique.ttf
# /usr/share/fonts/truetype/tlwg/TlwgTypist-Oblique.ttf
# /usr/share/fonts/truetype/tlwg/TlwgTypist.ttf
# /usr/share/fonts/truetype/tlwg/TlwgTypo-Bold.ttf
# /usr/share/fonts/truetype/tlwg/TlwgTypo-BoldOblique.ttf
# /usr/share/fonts/truetype/tlwg/TlwgTypo-Oblique.ttf
# /usr/share/fonts/truetype/tlwg/TlwgTypo.ttf
# /usr/share/fonts/truetype/tlwg/Umpush-Bold.ttf
# /usr/share/fonts/truetype/tlwg/Umpush-BoldOblique.ttf
# /usr/share/fonts/truetype/tlwg/Umpush-Light.ttf
# /usr/share/fonts/truetype/tlwg/Umpush-LightOblique.ttf
# /usr/share/fonts/truetype/tlwg/Umpush-Oblique.ttf
# /usr/share/fonts/truetype/tlwg/Umpush.ttf
# /usr/share/fonts/truetype/tlwg/Waree-Bold.ttf
# /usr/share/fonts/truetype/tlwg/Waree-BoldOblique.ttf
# /usr/share/fonts/truetype/tlwg/Waree-Oblique.ttf
# /usr/share/fonts/truetype/tlwg/Waree.ttf
# /usr/share/fonts/truetype/ttf-bitstream-vera/Vera.ttf
# /usr/share/fonts/truetype/ttf-bitstream-vera/VeraBI.ttf
# /usr/share/fonts/truetype/ttf-bitstream-vera/VeraBd.ttf
# /usr/share/fonts/truetype/ttf-bitstream-vera/VeraIt.ttf
# /usr/share/fonts/truetype/ttf-bitstream-vera/VeraMoBI.ttf
# /usr/share/fonts/truetype/ttf-bitstream-vera/VeraMoBd.ttf
# /usr/share/fonts/truetype/ttf-bitstream-vera/VeraMoIt.ttf
# /usr/share/fonts/truetype/ttf-bitstream-vera/VeraMono.ttf
# /usr/share/fonts/truetype/ttf-bitstream-vera/VeraSe.ttf
# /usr/share/fonts/truetype/ttf-bitstream-vera/VeraSeBd.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSans-Bold.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSans-BoldOblique.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSans-ExtraLight.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSans-Oblique.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSans.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSansCondensed-Bold.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSansCondensed-BoldOblique.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSansCondensed-Oblique.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSansCondensed.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSansMono-Bold.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSansMono-BoldOblique.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSansMono-Oblique.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSansMono.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSerif-Bold.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSerif-BoldItalic.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSerif-Italic.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSerif.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSerifCondensed-Bold.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSerifCondensed-BoldItalic.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSerifCondensed-Italic.ttf
# /usr/share/fonts/truetype/ttf-dejavu/DejaVuSerifCondensed.ttf
# /usr/share/fonts/truetype/ttf-indic-fonts-core/Kedage-b.ttf
# /usr/share/fonts/truetype/ttf-indic-fonts-core/Kedage-n.ttf
# /usr/share/fonts/truetype/ttf-indic-fonts-core/Malige-b.ttf
# /usr/share/fonts/truetype/ttf-indic-fonts-core/Malige-n.ttf
# /usr/share/fonts/truetype/ttf-indic-fonts-core/Meera_04.ttf
# /usr/share/fonts/truetype/ttf-indic-fonts-core/MuktiNarrow.ttf
# /usr/share/fonts/truetype/ttf-indic-fonts-core/MuktiNarrowBold.ttf
# /usr/share/fonts/truetype/ttf-indic-fonts-core/Pothana2000.ttf
# /usr/share/fonts/truetype/ttf-indic-fonts-core/Rachana_04.ttf
# /usr/share/fonts/truetype/ttf-indic-fonts-core/Rekha.ttf
# /usr/share/fonts/truetype/ttf-indic-fonts-core/Vemana.ttf
# /usr/share/fonts/truetype/ttf-indic-fonts-core/gargi.ttf
# /usr/share/fonts/truetype/ttf-indic-fonts-core/lohit_bn.ttf
# /usr/share/fonts/truetype/ttf-indic-fonts-core/lohit_gu.ttf
# /usr/share/fonts/truetype/ttf-indic-fonts-core/lohit_hi.ttf
# /usr/share/fonts/truetype/ttf-indic-fonts-core/lohit_ta.ttf
# /usr/share/fonts/truetype/ttf-indic-fonts-core/utkal.ttf
# /usr/share/fonts/truetype/ttf-khmeros-core/KhmerOS.ttf
# /usr/share/fonts/truetype/ttf-khmeros-core/KhmerOSsys.ttf
# /usr/share/fonts/truetype/ttf-xfree86-nonfree/luximb.ttf
# /usr/share/fonts/truetype/ttf-xfree86-nonfree/luximbi.ttf
# /usr/share/fonts/truetype/ttf-xfree86-nonfree/luximr.ttf
# /usr/share/fonts/truetype/ttf-xfree86-nonfree/luximri.ttf
# /usr/share/fonts/truetype/ttf-xfree86-nonfree/luxirb.ttf
# /usr/share/fonts/truetype/ttf-xfree86-nonfree/luxirbi.ttf
# /usr/share/fonts/truetype/ttf-xfree86-nonfree/luxirr.ttf
# /usr/share/fonts/truetype/ttf-xfree86-nonfree/luxirri.ttf
# /usr/share/fonts/truetype/ttf-xfree86-nonfree/luxisb.ttf
# /usr/share/fonts/truetype/ttf-xfree86-nonfree/luxisbi.ttf
# /usr/share/fonts/truetype/ttf-xfree86-nonfree/luxisr.ttf
# /usr/share/fonts/truetype/ttf-xfree86-nonfree/luxisri.ttf
# /usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-B.ttf
# /usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-BI.ttf
# /usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-C.ttf
# /usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-L.ttf
# /usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-LI.ttf
# /usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-M.ttf
# /usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-MI.ttf
# /usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-R.ttf
# /usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-RI.ttf
# /usr/share/fonts/truetype/ubuntu-font-family/UbuntuMono-B.ttf
# /usr/share/fonts/truetype/ubuntu-font-family/UbuntuMono-BI.ttf
# /usr/share/fonts/truetype/ubuntu-font-family/UbuntuMono-R.ttf
# /usr/share/fonts/truetype/ubuntu-font-family/UbuntuMono-RI.ttf
# /usr/share/fonts/truetype/unfonts-core/UnBatang.ttf
# /usr/share/fonts/truetype/unfonts-core/UnBatangBold.ttf
# /usr/share/fonts/truetype/unfonts-core/UnDinaru.ttf
# /usr/share/fonts/truetype/unfonts-core/UnDinaruBold.ttf
# /usr/share/fonts/truetype/unfonts-core/UnDinaruLight.ttf
# /usr/share/fonts/truetype/unfonts-core/UnDotum.ttf
# /usr/share/fonts/truetype/unfonts-core/UnDotumBold.ttf
# /usr/share/fonts/truetype/unfonts-core/UnGraphic.ttf
# /usr/share/fonts/truetype/unfonts-core/UnGraphicBold.ttf
# /usr/share/fonts/truetype/unfonts-core/UnGungseo.ttf
# /usr/share/fonts/truetype/unfonts-core/UnPilgi.ttf
# /usr/share/fonts/truetype/unfonts-core/UnPilgiBold.ttf
# /usr/share/fonts-droid/truetype/DroidSansFallback.ttf
# /usr/share/fonts-droid/truetype/DroidSansFallbackLegacy.ttf
# /usr/share/fonts-font-awesome/fonts/fontawesome-webfont.ttf
# /usr/share/ghostscript/9.18/Resource/CIDFSubst/DroidSansFallback.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/STIXGeneral.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/STIXGeneralBol.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/STIXGeneralBolIta.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/STIXGeneralItalic.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/STIXNonUni.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/STIXNonUniBol.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/STIXNonUniBolIta.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/STIXSizFiveSymReg.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymBol.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymReg.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymBol.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymReg.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymBol.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymReg.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymBol.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymReg.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/cmex10.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/cmr10.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/cmss10.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/cmsy10.ttf
# /usr/share/matplotlib/mpl-data/fonts/ttf/cmtt10.ttf
# /usr/share/qt5/doc/global/template/style/icomoon.ttf
# /usr/share/sphinx_rtd_theme/static/fonts/Inconsolata-Bold.ttf
# /usr/share/sphinx_rtd_theme/static/fonts/Inconsolata-Regular.ttf
# /usr/share/sphinx_rtd_theme/static/fonts/Lato-Bold.ttf
# /usr/share/sphinx_rtd_theme/static/fonts/Lato-Regular.ttf
# /usr/share/sphinx_rtd_theme/static/fonts/RobotoSlab-Bold.ttf
# /usr/share/sphinx_rtd_theme/static/fonts/RobotoSlab-Regular.ttf
# /usr/share/sphinx_rtd_theme/static/fonts/fontawesome-webfont.ttf
# /usr/share/vlc/skins2/fonts/FreeSans.ttf
# /usr/share/vlc/skins2/fonts/FreeSansBold.ttf
# /usr/share/wine/fonts/marlett.ttf
# /usr/share/wine/fonts/symbol.ttf
# /usr/share/wine/fonts/tahoma.ttf
# /usr/share/wine/fonts/tahomabd.ttf
# /usr/share/wine/fonts/wingding.ttf
# /var/lib/dpkg/alternatives/fonts-japanese-gothic.ttf
# /var/lib/gems/2.3.0/gems/prawn-0.12.0/data/fonts/Activa.ttf
# /var/lib/gems/2.3.0/gems/prawn-0.12.0/data/fonts/Chalkboard.ttf
# /var/lib/gems/2.3.0/gems/prawn-0.12.0/data/fonts/DejaVuSans.ttf
# /var/lib/gems/2.3.0/gems/prawn-0.12.0/data/fonts/Dustismo_Roman.ttf
# /var/lib/gems/2.3.0/gems/prawn-0.12.0/data/fonts/comicsans.ttf
# /var/lib/gems/2.3.0/gems/prawn-0.12.0/data/fonts/gkai00mp.ttf
# /var/lib/gems/2.3.0/gems/ttfunk-1.0.3/data/fonts/DejaVuSans.ttf
# /var/lib/gems/2.3.0/gems/ttfunk-1.0.3/data/fonts/comicsans.ttf
# /var/www/html/list/PHP-Redis/Quaker-Bak-working-GOOD/GOOD_QACK_BACK/Quacker/public/fonts/glyphicons/glyphicons-halflings-regular.ttf
# /var/www/html/list/PHP-Redis/Quaker-Bak-working-GOOD/Quacker/public/fonts/glyphicons/glyphicons-halflings-regular.ttf
# /var/www/html/list/PHP-Redis/bck/Quaker-Bak-working-GOOD/GOOD_QACK_BACK/Quacker/public/fonts/glyphicons/glyphicons-halflings-regular.ttf
# /var/www/html/list/PHP-Redis/bck/Quaker-Bak-working-GOOD/Quacker/public/fonts/glyphicons/glyphicons-halflings-regular.ttf
# /var/www/html/list/games/phaser-examples/examples/_site/css/fonts/BebasNeue-webfont.ttf
# /var/www/html/wordpress/wp-content/themes/twentyfifteen/genericons/Genericons.ttf
# /var/www/html/wordpress/wp-content/themes/twentysixteen/genericons/Genericons.ttf
# /var/www/html/wordpress/wp-includes/fonts/dashicons.ttf
# /var/www/html/wordpress/wp-includes/js/tinymce/skins/lightgray/fonts/tinymce-small.ttf
# /var/www/html/wordpress/wp-includes/js/tinymce/skins/lightgray/fonts/tinymce.ttf

# %%
# !ls instagram
# !showme instagram/postpalette01.jpg
# Out:
# 0001palette01.jpg  165160243-childrens-books.jpg  postpalette01.jpg
# 0002palette01.jpg  exchange20170827121605.png	  v2.png
# 0003palette01.jpg  exchange20170827124141.png

# %%
# %%writefile key.txt
# A human life he held to be a trifle in the big sum of time
# A heart-break for that kind is their salvation
# A man may be forgiven for a sin, but the effect remains
# A look too bright for joy, too intense for despair
# A sort of chuckle not entirely pleasant
# A man you could bank on, and draw your interest regular
# A left-handed boy is all right in the world
# A cloak of words to cover up the real thought behind
# Aboriginal in all of us, who must have a sign for an emotion Aboriginal dispersion
# Adaptability was his greatest weapon in life
# Advantage to live where nothing was required of her but truth
# After which comes steady happiness or the devil to pay (wedding)
# Agony in thinking about the things we're never going to do
# Ah, let it be soon!  Ah, let him die soon!
# Air of certainty and universal comprehension
# All humour in him had a strain of the sardonic
# All genius is at once a blessing or a curse
# All the world's mad but thee and me
# All men are worse than most women
# All is fair where all is foul
# QUOTES AND IMAGES FROM THE WORKS OF GILBERT PARKER
# All he has to do is to be vague, and look prodigious (Scientist)
# All are hurt some time
# Always hoping the best from the worst of us
# Always calling to something, for something outside ourselves
# An inner sorrow is a consuming fire
# And even envy praised her
# Anger was the least injurious of all grounds for separation
# Answered, with the indifference of despair
# Antipathy of the lesser to the greater nature
# Antipathy of the man in the wrong to the man in the right
# As if our penalties were only paid by ourselves!
# At first—and at the last—he was kind
# Ate some coffee-beans and drank some cold water
# Audience that patronisingly listens outside a room or window
# Awkward for your friends and gratifying to your enemies
# Babbling covers a lot of secrets
# Bad turns good sometimes, when you know the how
# Begin to see how near good is to evil
# Beginning of a lifetime of experience, comedy, and tragedy
# Being tired you can sleep, and in sleep you can forget
# Being generous with other people's money
# Being young, she exaggerated the importance of the event
# Being a man of very few ideas, he cherished those he had
# Beneath it all there was a little touch of ridicule
# Boldness without rashness, and hope without vain thinking
# But I don't think it is worth doing twice
# But to pay the vulgar penalty of prison—ah!
# But a wounded spirit who can bear
# But the years go on, and friends have an end
# Came of a race who set great store by mothers and grandmothers
# Carrying with him the warm atmosphere of a good woman's love
# Cherish any alleviating lie
# Clever men are trying
# Cling to beliefs long after conviction has been shattered
# Confidence in a weak world gets unearned profit often
# Conquest not important enough to satisfy ambition
# Counsel of the overwise to go jolting through the soul
# Courage which awaits the worst the world can do
# Courage; without which, men are as the standing straw
# Credulity, easily transmutable into superstition
# Damnable propinquity
# Dangerous man, as all enthusiasts are
# Death is not the worst of evils Death is a magnificent ally; it untangles knots
# Delicate revenge which hath its hour with every man
# Did not let him think that she was giving up anything for him
# Do what you feel you've got to do, and never mind what happens
# Does any human being know what he can bear of temptation
# Don't go at a fence till you're sure of your seat
# Don't be a bigger fool than there's any need to be
# Don't be too honest
# Down in her heart, loves to be mastered
# Duplicity, for which she might never
# have to ask forgiveness
# Each of us will prove himself a fool given perfect opportunity
# Egotism with which all are diseased
# Egregious egotism of young love there are only two identities
# Engrossed more, it seemed, in the malady than in the man
# Enjoy his own generosity
# Even bad company's better than no company at all
# Every true woman is a mother, though she have no child
# Every man should have laws of his own
# Every shot that kills ricochets
# Evil is half-accidental, half-natural
# Face flushed with a sort of pleasurable defiance
# Fascinating colour which makes evil appear to be good
# Fear a woman are when she hates, and when she loves
# Fear of one's own wife is the worst fear in the world
# Flood came which sweeps away the rust that gathers in the eyes
# Follow me; if I retreat, kill me; if I fall, avenge me
# For a man having work to do, woman, lovely woman, is rocks
# Freedom is the first essential of the artistic mind
# Frenchman, volatile, moody, chivalrous, unreasonable
# Frenchman,  slave of ideas, the victim of sentiment
# Friendship means a giving and a getting
# Futility of goodness, the futility of all
# Future of those who will not see, because to see is to suffer
# Good fathers think they have good daughters
# Good is often an occasion more than a condition
# Good thing for a man himself to be owed kindness
# Grove of pines to give a sense of warmth in winter
# Grow more intense, more convinced, more thorough, as they talk
# Had the luck together, all kinds and all weathers
# Had the slight flavour of the superior and the paternal
# He had a disdain for art and got unreasonably old
# Have not we all something to hide—with or without shame?
# Have you ever felt the hand of your own child in yours
# He had neither self-consciousness nor fear
# He admired, yet he wished to be admired
# He hated irony in anyone else
# He was not always sorry when his teasing hurt
# He felt things, he did not study them
# He was in fact not a philosopher, but a sentimentalist
# He had only made of his wife an incident in his life
# He didn't always side with the majority
# He does not love Pierre; but he does not pretend to love him
# He was strong enough to admit ignorance
# He has wheeled his nuptial bed into the street
# He had had acquaintances, but never friendships, and never loves
# He had no instinct for vice in the name of amusement
# He left his fellow-citizens very much alone
# He never saw an insult unless he intended to avenge it
# He had tasted freedom; he was near to license
# He borrowed no trouble
# He wishes to be rude to some one, and is disappointed
# He's a barber-shop philosopher
# Heaven where wives without number awaited him
# Her sight was bounded by the little field where she strayed
# Her voice had the steadiness of despair
# Her stronger soul ruled him without his knowledge
# Her own suffering always set her laughing at herself
# Highsterics, they call it
# His courtesy was not on the same expansive level as his vanity
# His duties were many, or he made them so
# His gift for lying was inexpressible
# Honesty was a thing he greatly desired—in others
# How little we can know to-day what we shall feel tomorrow
# How can one force one's heart?  No, no! One has to wait
# How many sons have ever added to their father's fame?
# How many conquests have been made in the name of God
# How can you judge the facts if you don't know the feeling?
# Hugging the chain of denial to his bosom
# Hunger for happiness is robbery
# I love that love in which I married him
# I was never good at catechism
# I said I was not falling in love .. I am in love
# I am only myself when I am drunk
# I have a good memory for forgetting
# I don't wish to fit in; things must fit me
# I like when I like, and I like a lot when I like
# I always did what was wrong, and liked it—nearly always
# I should remember to forget it
# I don't believe in walking just for the sake of walking
# I don't think.  I'm old enough to know
# I can't pay you for your kindness to me, and I don't want to
# I had to listen to him, and he had to pay me for listening
# I was born insolent
# I—couldn't help it
# If you have a good thought, act on it
# If one remembers, why should the other forget
# If women hadn't memory, she answered, they wouldn't have much
# If fumbling human fingers do not meddle with it
# Illusive hopes and irresponsible deceptions
# Imagination is at the root of much that passes for love
# Importunity with discretion was his motto
# In all secrets there is a kind of guilt
# In her heart she never can defy the world as does a man
# Inclined to resent his own insignificance
# Instinct for detecting veracity, having practised on both sides
# Interfere with people who had a trade and didn't understand it
# Irishmen have gifts for only two things—words and women
# Is the habit of good living mere habit and mere acting
# It is hard to be polite to cowards
# It is not Justice that fills the gaols, but Law
# It is not the broken heart that kills, but broken pride
# It is good to live, isn't it?
# It is difficult to be idle and important too
# It is not much to kill or to die that is in the game
# It isn't what they do, it's what they don't do
# It ain't for us to say what we're goin' to be, not always
# It is easy to repent when our pleasures have palled
# It's the people who try to be clever who never are
# It's no good simply going—you've gotto go somewhere
# Jews everywhere treated worse than the Chinaman
# Joy of a confessional which relieves the sick heart
# Kissed her twice on the cheek—the first time in fifteen years
# Knew the lie of silence to be as evil as the lie of speech
# Knew when to shut his eyes, and when to keep them open
# Know how bad are you, and don't care
# Knowing that his face would never be turned from me
# Lacks a balance-wheel.  He has brains, but not enough
# Law is expensive whether you win or lose
# Learned what fools we mortals be
# Learned, as we all must learn, that we live our dark hour alone
# Let others ride to glory, I'll shoe their horses for the gallop
# Liars all men may be, but to wild women or landlords
# Life is only futile to the futile
# Lighted candles in hollowed pumpkins
# Likenesses between the perfectly human and the perfectly animal
# Lilt of existence lulling to sleep wisdom and tried experience
# Liquor makes me human
# Live and let live is doing good
# Lonely we come into the world, and lonely we go out of it
# Longed to touch, oftener than they did, the hands of children
# Lose their heads, and be so absurdly earnest
# Love can outlive slander
# Love, too, is a game, and needs playing
# Love knows not distance; it hath no continent
# Love has nothing  to do with ugliness or beauty, or fortune
# Lyrical in his enthusiasms
# Man who tells the story in a new way, that is genius
# Man grows old only by what he suffers, and what he forgives
# Man or woman must not expect too much out of life
# May be more beautiful in uncertain England than anywhere else
# Meditation is the enemy of action
# Memory is man's greatest friend and worst enemy
# Men and women are unwittingly their own executioners
# Men feel surer of women than women feel of men
# Men do not steal up here: that is the unpardonable crime
# Men must have their bad hours alone
# Men are like dogs, they worship him who beats them
# Men are shy with each other where their emotions are in play
# Miseries of this world are caused by forcing issues
# Missed being a genius by an inch
# Monotonously intelligent
# More idle than wicked
# Most honest thing I ever heard, but it's not the most truthful
# Most important lessons of life,never to quarrel with a woman
# Mothers always forgive
# My excuses were making bad infernally worse
# Mystery is dear to a woman's heart
# Nature twists in back, or  anywhere, gets a twist in's brain too
# Nervous legs at a gallop
# Never believed that when man or woman said no that no was meant
# Never looked to get an immense amount of happiness out of life
# Never to be content with superficial reasons and the obvious
# Never give up your soul to things only, keep it for people
# No note of praise could be pitched too high for Elizabeth
# No, I'm not good—I'm only beautiful
# No news—no trouble
# No virtue in not falling, when you're not tempted
# No past that is hidden has ever been a happy past
# No man so simply sincere, or so extraordinarily prejudiced
# Noise is not battle
# Not good to have one thing in the head all the time
# Not content to do even the smallest thing ill
# Not to show surprise at anything
# Nothing so good as courage, nothing so base as the shifting eye
# Nothing is futile that is right
# Nothing so popular for the moment as the fall of a favourite
# Of those who hypnotize themselves, who glow with self-creation
# Of course I've hated, or I wouldn't be worth a button
# Often called an invention of the devil (Violin)
# Often, we would rather be hurt than hurt
# One does the work and another gets paid
# One always buys back the past at a tremendous price
# One doesn't choose to worry
# One favour is always the promise of another
# Only the supremely wise or the deeply ignorant who never alter
# Oriental would think not less of him for dissimulation
# Paradoxes which make for laughter—and for tears
# Passion to forget themselves
# Pathetically  in earnest
# People who are clever never think of trying to be
# Philosophers are often stupid in human affairs
# Philosophy which could separate the petty from the prodigious
# Political virtue goes unrewarded
# Prepared for a kiss this hour and a reproach the next
# Preserved a marked unconsciousness
# Protest that it is right when it knows that it is wrong
# Put the matter on your own hearthstone
# Queer that things which hurt most can't be punished by law
# Rack of secrecy, the cruelest inquisition of life
# Reading a lot and forgetting everything
# Reconciling the preacher and the sinner, as many another has
# Religion to him was a dull recreation invented chiefly for women
# Remember the sorrow of thine own wife
# Remember your own sins before you charge others
# Rewarded for its mistakes
# Romance is an incident to a man
# Sacrifice to the god of the pin-hole
# Sardonic pleasure in the miseries of the world
# Saw how futile was much competition
# Saying uncomfortable things in a deferential way
# Scoundrel, too weak to face the consequences of his sin
# Secret of life: to keep your own commandments
# Self-will, self-pride, and self-righteousness were big in him
# She lacked sense a little and sensitiveness much
# She was not to be forced to answer his arguments directly
# She knew what to say and what to leave unsaid
# She was beginning to understand that evil is not absolute
# She valued what others found useless
# She wasn't young, but she seemed so
# She had not suffered that sickness, social artifice
# She had provoked love, but had never given it
# She had never stooped to conquer
# Should not make our own personal experience a law unto the world
# Simply to have death renewed every morning
# Slander ever scorches where it touches
# Slow-footed hours wandered by, leaving apathy in their train
# Smiling was part of his equipment
# So say your prayers, believe all you can, don't ask questions
# Solitude fixes our hearts immovably on things
# Some people are rough with the poor—and proud
# Some wise men are fools, one way or another
# Some are hurt in one way and some in another
# Sometimes the longest way round is the shortest way home
# Soul tortured through different degrees of misunderstanding
# Spurting out little geysers of other people's cheap wisdom
# Still the end of your existence, I rejoined—to be amused?
# Strike first and heal after—"a kick and a lick"
# Struggle of conscience and expediency
# Surely she might weep a little for herself
# Suspicion, the bane of sick old age
# Sympathy, with curiousness in their eyes and as much inhumanity
# Sympathy and consolation might be much misplaced
# Thanked him in her heart for the things he had left unsaid
# That anxious civility which beauty can inspire
# That iceberg which most mourners carry in their breasts
# That he will find the room empty where I am not
# The Government cherish the Injin much in these days
# The Injin speaks the truth, perhaps—eye of red man multiplies
# The blind tyranny of the just
# The soul of goodness in things evil
# The higher we go the faster we live
# The gods made last to humble the pride of men—there was rum
# The world never welcomes its deserters
# The furious music of death and war was over
# The tender care of a woman—than many pharmacopoeias
# The beginning of the end of things was come for him
# The ravings of a sick man are not always counted ravings
# The friendship of man is like the shade of the acacia
# The sea is a great breeder of friendship
# The vague pain of suffered indifference
# The soul is a great traveller
# The happy scene of the play before the villain comes in
# The threshold of an acknowledged love
# The Barracks of the Free
# The real business of life is trying to understand each other
# The world is not so bad as is claimed for it
# The temerity and nonchalance of despair
# There is nothing so tragic as the formal
# There are things we repent of which cannot be repaired
# There is something humiliating in even an undeserved injury
# There should be written the one word, "Wait"
# There is no refuge from memory and remorse in this world
# There was never a grey wind but there's a greyer
# There is no influence like the influence of habit
# There is no habit so powerful as the habit of care of others
# There's no credit in not doing what you don't want to do
# These little pieces of art make life possible
# Out:
# Overwriting key.txt

# %%
# %%writefile wordcloud.txt
# Python
# Programming
# ImageBot
# Enjoy
# f4f always
# Just for You
# Good Stuff
# Computer Graphics
# Python Fun
# Computer Fun
# Art Love
# Computer Creations
# Programming Art
# Visualization
# Random Art
# Python Graphics
# Generator
# Followback
# Word Cloud
# Graphics
# Fun w/Python
# Python Stuff
# PYTHON !!!
# Follow4Follow
# Love`en Python
# Creative Python
# Graphic Fun
# ImageBot
# Programming
# Out:
# Overwriting wordcloud.txt

# %%
# %reset -f

# %%
#ONE TIME MANUAL POSTS
#!/home/jack/anaconda2/python
import random
from random import randint
import time
import markovify
import os
import sys
sys.path.insert(1, "/home/jack/anaconda2/envs/py27/lib/python2.7/site-packages")
import twython
from twython import Twython
from PIL import Image, ImageChops, ImageDraw, ImageFont, ImageFilter
custom = "junk/mixpalette.png"
filename0=(custom)
def generate_the_word(infile):
        with open(infile) as f:
            contents_of_file = f.read()
        lines = contents_of_file.splitlines()
        line_number = random.randrange(0, len(lines))
        return lines[line_number]

def draw_text_with_halo(img, position, text, font, col, halo_col):
    #halo = Image.new('RGBA', img.size, (0, 0, 0, 0))
    halo = Image.new('RGBA', img.size, (255,255,255, 0))
    ImageDraw.Draw(halo).text(position, text, font = font, fill = halo_col)
    blurred_halo = halo.filter(ImageFilter.BLUR)
    ImageDraw.Draw(blurred_halo).text(position, text, font = font, fill = col)
    return Image.composite(img, blurred_halo, ImageChops.invert(blurred_halo))

if __name__ == '__main__':
    inp = Image.open(filename0)
    font = ImageFont.truetype("/home/jack/.fonts/Exo-Black.ttf", 45)
    #font = ImageFont.truetype("/home/jack/.fonts/GRUNTREAPER.ttf", 70)
    #font = ImageFont.truetype("/home/jack/.fonts/Nightbird.ttf", 70)
    #font = ImageFont.truetype("/home/jack/.fonts/Nightbird.ttf", 70)
    #font = ImageFont.truetype("/home/jack/.fonts/Punktype.ttf", 70)
    text_col = (255,200,0) # bright green
    halo_col = (0, 0,0)   # black
    #text_col = (230, 230,250) # bright green
    #halo_col = (0,0,0)  # black (0,0,0)    
    textin = (generate_the_word("wordcloud.txt"))
    #i2 = draw_text_with_halo(inp, (15, 8), "HIGH FIVE", font, text_col, halo_col)
    i2 = draw_text_with_halo(inp, (235, 410), "MIXED PALETTES", font, text_col, halo_col)
    #txt = Image.new('RGBA', i.size, (255,255,255,0))

    # get a font
    fnt = ImageFont.truetype("/home/jack/.fonts/Exo-Black.ttf", 20)
    
    # get a drawing context
    width, height = inp.size
    marginx = 225
    marginy = 35
    x = width - marginx
    y = height - marginy
    signature_ = "The TwitterBot Project" 
    text_col2 = (15, 5, 10) # bright green
    halo_col2 = (255, 255,255) 
    #text_col2 = (255, 255,255) # signature white
    #halo_col2 = (0, 0, 0)   # signature black
    txt=draw_text_with_halo(i2,(x,y), signature_, fnt, text_col2, halo_col2)
    out = Image.alpha_composite(i2, txt)
    out.save("tmp/TM_POST.jpg")

#removed keys for privacy reasons
CONSUMER_KEY = 'xxxxxxxxxxx'
CONSUMER_SECRET = 'xxxxxxxxxxxxxxxxxxx'
ACCESS_KEY = 'xxxxxxxxxxxxxxxxx'
ACCESS_SECRET = 'xxxxxxxxxxxxxxxxxxx'

twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_KEY, ACCESS_SECRET)
#path = 'images/NewFolder'
f = open("art.txt")
text = f.read()
# Build the model.
text_model = markovify.Text(text)
# Print randomly-generated sentences of no more than 140 characters
#http://paulbourke.net/fractals/
#STR = (text_model.make_short_sentence(140))
STR = ("$Python $Imagery $Redneck #filipina #filipinowoman posted with #JupyterNotebook.")
#PATH = "/home/jack/Desktop/deep-dream-generator/notebooks/STUFF/experiment/experiment8.jpg"
PATH = "tmp/TM_POST.jpg"
# 1 , 2, 3, 12, 5, 15, 8, 6
#photo = open('/home/jack/Desktop/deep-dream-generator/notebooks/images/'+file_list[rnd]+'.jpg','rb')

photo = open(PATH,'rb')
response = twitter.upload_media(media=photo)
twitter.update_status(status=STR, media_ids=[response['media_id']])
#!showme tmp/TM_POST.jpg
# Out:
# {u'contributors': None,
#  u'coordinates': None,
#  u'created_at': u'Mon Aug 28 05:52:45 +0000 2017',
#  u'entities': {u'hashtags': [{u'indices': [26, 35], u'text': u'filipina'},
#    {u'indices': [36, 50], u'text': u'filipinowoman'},
#    {u'indices': [63, 79], u'text': u'JupyterNotebook'}],
#   u'media': [{u'display_url': u'pic.twitter.com/5KCaDSQCTp',
#     u'expanded_url': u'https://twitter.com/JackLNorthrup/status/902046275628974080/photo/1',
#     u'id': 902046271573180416,
#     u'id_str': u'902046271573180416',
#     u'indices': [81, 104],
#     u'media_url': u'http://pbs.twimg.com/media/DIS2TgQVwAA-LEe.jpg',
#     u'media_url_https': u'https://pbs.twimg.com/media/DIS2TgQVwAA-LEe.jpg',
#     u'sizes': {u'large': {u'h': 640, u'resize': u'fit', u'w': 640},
#      u'medium': {u'h': 640, u'resize': u'fit', u'w': 640},
#      u'small': {u'h': 640, u'resize': u'fit', u'w': 640},
#      u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#     u'type': u'photo',
#     u'url': u'https://t.co/5KCaDSQCTp'}],
#   u'symbols': [{u'indices': [0, 7], u'text': u'Python'}],
#   u'urls': [],
#   u'user_mentions': []},
#  u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/5KCaDSQCTp',
#     u'expanded_url': u'https://twitter.com/JackLNorthrup/status/902046275628974080/photo/1',
#     u'id': 902046271573180416,
#     u'id_str': u'902046271573180416',
#     u'indices': [81, 104],
#     u'media_url': u'http://pbs.twimg.com/media/DIS2TgQVwAA-LEe.jpg',
#     u'media_url_https': u'https://pbs.twimg.com/media/DIS2TgQVwAA-LEe.jpg',
#     u'sizes': {u'large': {u'h': 640, u'resize': u'fit', u'w': 640},
#      u'medium': {u'h': 640, u'resize': u'fit', u'w': 640},
#      u'small': {u'h': 640, u'resize': u'fit', u'w': 640},
#      u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#     u'type': u'photo',
#     u'url': u'https://t.co/5KCaDSQCTp'}]},
#  u'favorite_count': 0,
#  u'favorited': False,
#  u'geo': None,
#  u'id': 902046275628974080,
#  u'id_str': u'902046275628974080',
#  u'in_reply_to_screen_name': None,
#  u'in_reply_to_status_id': None,
#  u'in_reply_to_status_id_str': None,
#  u'in_reply_to_user_id': None,
#  u'in_reply_to_user_id_str': None,
#  u'is_quote_status': False,
#  u'lang': u'en',
#  u'place': None,
#  u'possibly_sensitive': False,
#  u'retweet_count': 0,
#  u'retweeted': False,
#  u'source': u'<a href="http://blogblocks.org" rel="nofollow">jack_watch</a>',
#  u'text': u'$Python $Imagery $Redneck #filipina #filipinowoman posted with #JupyterNotebook. https://t.co/5KCaDSQCTp',
#  u'truncated': False,
#  u'user': {u'contributors_enabled': False,
#   u'created_at': u'Wed May 11 16:01:29 +0000 2011',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u"Overcome with addictions: PHP, Python, Nodejs, JavaScript, P5.J's, Processing.J's, Ruby, MySql, Mongo, HTML, CSS, Docker, Bash scripting, C++, Linux, Android.",
#   u'entities': {u'description': {u'urls': []},
#    u'url': {u'urls': [{u'display_url': u'jacknorthrup.com',
#       u'expanded_url': u'http://jacknorthrup.com',
#       u'indices': [0, 23],
#       u'url': u'https://t.co/SFgB3ME7hP'}]}},
#   u'favourites_count': 546,
#   u'follow_request_sent': False,
#   u'followers_count': 1067,
#   u'following': False,
#   u'friends_count': 1131,
#   u'geo_enabled': True,
#   u'has_extended_profile': False,
#   u'id': 296906916,
#   u'id_str': u'296906916',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 37,
#   u'location': u'Philippines via USA',
#   u'name': u'Jack Northrup',
#   u'notifications': False,
#   u'profile_background_color': u'C0DEED',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/837212066/b7a2e43cb82aa9f56c16b6afb60944fe.png',
#   u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/837212066/b7a2e43cb82aa9f56c16b6afb60944fe.png',
#   u'profile_background_tile': True,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/296906916/1502958210',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/2765370268/48e94b4ba63cc542d5e0967136165bec_normal.png',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/2765370268/48e94b4ba63cc542d5e0967136165bec_normal.png',
#   u'profile_link_color': u'F70A1D',
#   u'profile_sidebar_border_color': u'FFFFFF',
#   u'profile_sidebar_fill_color': u'DDEEF6',
#   u'profile_text_color': u'333333',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'JackLNorthrup',
#   u'statuses_count': 4078,
#   u'time_zone': u'Central Time (US & Canada)',
#   u'translator_type': u'none',
#   u'url': u'https://t.co/SFgB3ME7hP',
#   u'utc_offset': -18000,
#   u'verified': False}}

# %%
# !showme tmp/TM_POST.jpg

# %%
from PIL import Image, ImageOps, ImagePalette
#im = Image.open("crawler1/0010van_gogh.jpg")
imm = Image.open("AUGpost-/20170825171104.png")
img2 = imm.getdata()
im3 = Image.open("junk/gray_van_gogh.jpg").convert('L')
#im3.putpalette(im2)

# %%
from PIL import Image, ImageOps, ImagePalette
im = Image.open("crawler1/0010van_gogh.jpg").convert('LA').convert('RGB')
im.save('junk/gray_van_gogh.jpg')
im = Image.open("junk/gray_van_gogh.jpg").convert('L')
#im.load() # make sure it's loaded into memory
assert im.mode == "L"

imm = Image.open("AUGpost-/20170825171104.png")
img2 = imm.getdata()

im.putpalette(img2)
assert im.mode == "P" # now has a palette
im.save("junk/assert_van_gogh.png")
im
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-98a81eedc49d> in <module>()
#       9 img2 = imm.getdata()
#      10
# ---> 11 im.putpalette(img2)
#      12 assert im.mode == "P" # now has a palette
#      13 im.save("junk/assert_van_gogh.png")
#
# /home/jack/anaconda2/lib/python2.7/site-packages/PIL/Image.pyc in putpalette(self, data, rawmode)
#    1498         self.palette = palette
#    1499         self.palette.mode = "RGB"
# -> 1500         self.load()  # install new palette
#    1501
#    1502     def putpixel(self, xy, value):
#
# /home/jack/anaconda2/lib/python2.7/site-packages/PIL/Image.pyc in load(self)
#     774         if self.im and self.palette and self.palette.dirty:
#     775             # realize palette
# --> 776             self.im.putpalette(*self.palette.getdata())
#     777             self.palette.dirty = 0
#     778             self.palette.mode = "RGB"
#
# ValueError: invalid palette size

# %%
from PIL import Image, ImageOps
im = Image.open("crawler1/0010van_gogh.jpg").convert('LA').convert('RGB')
im.save('junk/gray_van_gogh.jpg')
im = Image.open("junk/gray_van_gogh.jpg").convert('L')
#im.load() # make sure it's loaded into memory
assert im.mode == "L"
# create a lookup table (r, g, b, r, g, b, r, g, b, ...)
lut = []
for i in range(186):
    lut.extend([255-i, i/2, i])
im.putpalette(lut)
assert im.mode == "P" # now has a palette
im.save("junk/assert_van_gogh.png")
im
# Out:
# <PIL.Image.Image image mode=P size=640x640 at 0x7FBED15A8FD0>

# %%
from PIL import Image, ImageOps
im = Image.open("crawler1/0010van_gogh.jpg").convert('LA').convert('RGB')
im.save('junk/gray_van_gogh.jpg')
im = Image.open("junk/gray_van_gogh.jpg").convert('L')
#im.load() # make sure it's loaded into memory
assert im.mode == "L"
# create a lookup table (r, g, b, r, g, b, r, g, b, ...)
lut = []
for i in range(256):
    lut.extend([255-i, i/2, i])
im.putpalette(lut)
assert im.mode == "P" # now has a palette
im.save("junk/assert_van_gogh.png")
im
# Out:
# <PIL.Image.Image image mode=P size=640x640 at 0x7FBED164BA50>

# %%
from PIL import Image
oldimage = Image.open("crawler1/0010van_gogh.jpg")
palettedata = [0, 0, 0, 102, 102, 102, 176, 176, 176, 255, 255, 255]
newimage = Image.new('P', oldimage.size)
newimage.putpalette(palettedata * 64)
newimage.paste(oldimage, (0, 0) + oldimage.size)
newimage.show()

# %%
# Given: arr and arr2 of RGB color data
img = Image.fromarray(arr)
img = img.convert('P', palette=Image.ADAPTIVE, colors=16)

img2 = Image.fromarray(arr2)
img2 = img2.convert('P', palette=img.getpalette(), colors=16)

# %%
#!/usr/bin/env python3 
from PIL import Image 
def quantizetopalette(silf, palette, dither=False): 
    """Convert an RGB or L mode image to 
    use a given P image's palette.""" 
    silf.load() 
    # use palette from reference image 
    palette.load() 
if palette.mode != "P": raise ValueError("bad mode for palette image") 
    if silf.mode != "RGB" and silf.mode != "L": 
        raise ValueError( "only RGB or L mode images can be quantized to a palette" ) 
        im = silf.im.convert("P", 1 if dither else 0, palette.im) 
        # the 0 above means turn OFF dithering 
    return silf._makeself(im) 
        
    palettedata = [0, 0, 0, 102, 102, 102, 176, 176, 176, 255, 255, 255] 
    
    palimage = Image.new('P', (16, 16)) palimage.putpalette(palettedata * 64) 
    
    oldimage = Image.open("School_scrollable1.png") 
    
    newimage = quantizetopalette(oldimage, palimage, dither=False) newimage.show()
# Out:
#   File "<ipython-input-1-8e11aa11682b>", line 10
#     if silf.mode != "RGB" and silf.mode != "L":
#     ^
# IndentationError: unexpected indent

# %%
# !showme tmp/TM_POST.jpg

# %% [markdown]
# ## Picks a Random Image and Random Titles
# ## Also and Signs and Posts to Twitter

# %%
Easy to customize with various title sizes, colors. and locations.

# %%
# %%writefile wordcloud.txt
# Python
# Programming
# ImageBot
# Enjoy
# f4f always
# Just for You
# Good Stuff
# Computer Graphics
# Python Fun
# Python Graphics
# Generator
# Followback
# Word Cloud
# Graphics
# Fun w/Python
# Python Stuff
# PYTHON !!!
# Follow4Follow
# Love`en Python
# Creative Python
# Graphic Fun
# ImageBot
# Programming
# Out:
# Overwriting wordcloud.txt

# %%
from PIL import Image
import os
import cv2
path = r"aug25PM/"
#path = r"crawler4/"
base_image = random.choice([
    x for x in os.listdir(path)
    if os.path.isfile(os.path.join(path, x))
    ])
filename0=(path+base_image)
im = Image.open(filename0)
imP = im.convert('RGB').convert('P', palette=Image.ADAPTIVE, colors=6)
imP.putpalette([
     243,164,10,
     157,17,17,
     66,99,166,
     70,155,53,
     0,0,0,
     70,70,140,
     ])


im2 = Image.open(filename0)
mask0 = im2.convert('L') # need a greyscale image to create a mask
mask = Image.eval(mask0, lambda a: 255 if a == 0 else 0)
mask = mask.filter(ImageFilter.MinFilter(3))
imP.paste(2, mask) # Paste the color of index 2 using image2 as a mask
filename = time.strftime("AUGpost/%Y%m%d%H%M%S.png")
imP
# Out:
# <PIL.Image.Image image mode=P size=640x640 at 0x7F5F4C0FE950>

# %%
imP.save(filename)
print filename
# Out:
# AUGpost/20170825162322.png

# %%
# %%writefile titlenpost
# #!/bin/bash
#
# while true; do
#   python titlenpost.py
#   echo "posted :"
#   date
#   sleep 800s
# done
# Out:
# Writing titlenpost

# %%
from PIL import Image
import os
path = r"aug25PM/"
#path = r"crawler4/"
base_image = random.choice([
    x for x in os.listdir(path)
    if os.path.isfile(os.path.join(path, x))
    ])
filename0=(path+base_image)
im = Image.open(filename0)
imP = im.convert('RGB').convert('P', palette=Image.ADAPTIVE, colors=6)
imP.putpalette([
    243,164,10,
    157,17,17,
    66,99,166,
    70,155,53,
    0,0,0,
    188,160,12,
    ])


im2 = Image.open(filename0)
mask0 = im2.convert('L') # need a greyscale image to create a mask
mask = Image.eval(mask0, lambda a: 255 if a == 0 else 0)

imP.paste(2, mask) # Paste the color of index 2 using image2 as a mask



imP
# Out:
# <PIL.Image.Image image mode=P size=640x640 at 0x7F5F4F23E550>

# %%
# !mkdir AUGpost

# %%
imP.save(filename)
print filename
# Out:
# AUGpost/20170825161136.png

# %%
from PIL import Image
import os
import cv2
path = r"aug25PM/"
#path = r"crawler4/"
base_image = random.choice([
    x for x in os.listdir(path)
    if os.path.isfile(os.path.join(path, x))
    ])
filename0=(path+base_image)
im = Image.open(filename0)
imP = im.convert('RGB').convert('P', palette=Image.ADAPTIVE, colors=6)
imP.putpalette([
    243,164,10,
    157,17,17,
    66,99,166,
    70,155,53,
    0,0,0,
    188,160,12,
    ])


im2 = Image.open(filename0)
mask0 = im2.convert('L') # need a greyscale image to create a mask
mask = Image.eval(mask0, lambda a: 255 if a == 0 else 0)

mask.save("tmp/mask.png")
mask= Image.open("tmp/mask.png")

mask = mask.filter(ImageFilter.MinFilter(3))
#mask = mask.filter(ImageFilter.BLUR)
imP.paste(2, mask) # Paste the color of index 2 using image2 as a mask



imP
# Out:
# <PIL.Image.Image image mode=P size=640x640 at 0x7F5F4C13DA90>

# %%
# !mkdir AUG_post

# %%
#good combos

imP.putpalette([
        142,124,210,
        27,217,117,
        120,72,120,
        110,20,120,
        ])

# %%
from PIL import Image
import os
import sys
import time
count=0
while count<15:
    path = r"aug25/"
    #path = r"crawler4/"
    base_image = random.choice([
        x for x in os.listdir(path)
        if os.path.isfile(os.path.join(path, x))
        ])
    filename0=(path+base_image)
    im = Image.open(filename0)
    imP = im.convert('RGB').convert('P', palette=Image.ADAPTIVE, colors=4)
    imP.putpalette([
        152,124,10,
        47,251,117,
        120,172,122,
        110,20,120,
        ])


    im2 = Image.open(filename0)
    mask0 = im2.convert('L') # need a greyscale image to create a mask
    mask = Image.eval(mask0, lambda a: 255 if a == 0 else 0)
    mask = mask.filter(ImageFilter.MinFilter(3))
    imP.paste(2, mask) # Paste the color of index 2 using image2 as a mask
    filename = time.strftime("aug25PM/%Y%m%d%H%M%S.png")
    time.sleep(2)
    imP.save(filename)
    count=count+1

# %%
imP.save('junk/out3.png') # Save and set index 0 as transparent

# %%
#Great signature
import sys
import os
import time
import random
from PIL import Image, ImageChops, ImageDraw, ImageFont, ImageFilter
path = r"colorful/"
base_image = random.choice([
    x for x in os.listdir(path)
    if os.path.isfile(os.path.join(path, x))
])
filename0=(path+base_image)
def generate_the_word(infile):
        with open(infile) as f:
            contents_of_file = f.read()
        lines = contents_of_file.splitlines()
        line_number = random.randrange(0, len(lines))
        return lines[line_number]

def draw_text_with_halo(img, position, text, font, col, halo_col):
    halo = Image.new('RGBA', img.size, (0, 0, 0, 0))
    ImageDraw.Draw(halo).text(position, text, font = font, fill = halo_col)
    blurred_halo = halo.filter(ImageFilter.BLUR)
    ImageDraw.Draw(blurred_halo).text(position, text, font = font, fill = col)
    return Image.composite(img, blurred_halo, ImageChops.invert(blurred_halo))

if __name__ == '__main__':
    inp = Image.open(filename0)
    font = ImageFont.truetype("/home/jack/.fonts/Exo-Black.ttf", 40)
    text_col = (255, 255,230) # bright green
    halo_col = (0, 0, 0)   # black
    textin = (generate_the_word("wordcloud.txt"))
    i2 = draw_text_with_halo(inp, (15, 8), textin, font, text_col, halo_col)
    
    #txt = Image.new('RGBA', i.size, (255,255,255,0))

    # get a font
    fnt = ImageFont.truetype("/home/jack/.fonts/Exo-Black.ttf", 20)
    
    
    width, height = inp.size
    marginx = 225
    marginy = 35
    x = width - marginx
    y = height - marginy
    signature_ = "The TwitterBot Project" 
    #text_col2 = (150, 255, 150) # bright green
    #halo_col2 = (0, 0, 0)   # black
    text_col2 = (255, 255,230) # bright green
    halo_col2 = (0, 0, 0)   # black
    txt=draw_text_with_halo(i2,(x,y), signature_, fnt, text_col2, halo_col2)
    d = ImageDraw.Draw(txt)
    out = Image.alpha_composite(i2, txt)
    filename = time.strftime("colorful/%Y%m%d%H%M%S.jpg")


out
# Out:
# <PIL.Image.Image image mode=RGBA size=640x640 at 0x7F5F61E502D0>

# %%
out.save(filename)

# %%
# %%writefile titlenpost.py
#!/home/jack/anaconda2/python
import random
from random import randint
import time
import markovify
import os
import sys
sys.path.insert(1, "/home/jack/anaconda2/envs/py27/lib/python2.7/site-packages")
import twython
from twython import Twython
from PIL import Image, ImageChops, ImageDraw, ImageFont, ImageFilter
nap = randint(10,35)
time.sleep(nap)
path = r"publish/"
base_image = random.choice([
    x for x in os.listdir(path)
    if os.path.isfile(os.path.join(path, x))
])
filename0=(path+base_image)
def generate_the_word(infile):
        with open(infile) as f:
            contents_of_file = f.read()
        lines = contents_of_file.splitlines()
        line_number = random.randrange(0, len(lines))
        return lines[line_number]

def draw_text_with_halo(img, position, text, font, col, halo_col):
    halo = Image.new('RGBA', img.size, (0, 0, 0, 0))
    ImageDraw.Draw(halo).text(position, text, font = font, fill = halo_col)
    blurred_halo = halo.filter(ImageFilter.BLUR)
    ImageDraw.Draw(blurred_halo).text(position, text, font = font, fill = col)
    return Image.composite(img, blurred_halo, ImageChops.invert(blurred_halo))

if __name__ == '__main__':
    inp = Image.open(filename0)
    font = ImageFont.truetype("/home/jack/.fonts/Exo-Black.ttf", 40)
    text_col = (255, 255,230) # bright green
    halo_col = (0, 0, 0)   # black
    textin = (generate_the_word("wordcloud.txt"))
    i2 = draw_text_with_halo(inp, (15, 8), "I_FollowBack", font, text_col, halo_col)
    
    #txt = Image.new('RGBA', i.size, (255,255,255,0))

    # get a font
    fnt = ImageFont.truetype("/home/jack/.fonts/Exo-Black.ttf", 20)
    # get a drawing context
    width, height = inp.size
    marginx = 225
    marginy = 35
    x = width - marginx
    y = height - marginy
    signature_ = "The TwitterBot Project" 
    #text_col2 = (150, 255, 150) # bright green
    #halo_col2 = (0, 0, 0)   # black
    text_col2 = (255, 255,230) # bright green
    halo_col2 = (0, 0, 0)   # black
    txt=draw_text_with_halo(i2,(x,y), signature_, fnt, text_col2, halo_col2)
    out = Image.alpha_composite(i2, txt)
    out.save("tmp/TM_POST.jpg")

#removed keys for privacy reasons
CONSUMER_KEY = 'xxxxxxxxxx'
CONSUMER_SECRET = 'xxxxxxxxx'
ACCESS_KEY = 'xxxxxxxxxxxxxxxxxx'
ACCESS_SECRET = 'xxxxxxxxxxxxxxxxxxxxx'

twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_KEY, ACCESS_SECRET)
#path = 'images/NewFolder'
f = open("art.txt")
text = f.read()
# Build the model.
text_model = markovify.Text(text)
# Print randomly-generated sentences of no more than 140 characters
#http://paulbourke.net/fractals/
STR = (text_model.make_short_sentence(140))
#STR = ("#All_in_One - #WordCloud #Create - Added ability to randomly choose an image background  #Automated")
#PATH = "/home/jack/Desktop/deep-dream-generator/notebooks/STUFF/experiment/experiment8.jpg"
PATH = "tmp/TM_POST.jpg"
# 1 , 2, 3, 12, 5, 15, 8, 6
#photo = open('/home/jack/Desktop/deep-dream-generator/notebooks/images/'+file_list[rnd]+'.jpg','rb')

photo = open(PATH,'rb')
response = twitter.upload_media(media=photo)
twitter.update_status(status=STR, media_ids=[response['media_id']])
# Out:
# Overwriting titlenpost.py

# %%
#%%writefile titlenpost.py
#!/home/jack/anaconda2/python
import random
from random import randint
import time
import markovify
import os
import sys
sys.path.insert(1, "/home/jack/anaconda2/envs/py27/lib/python2.7/site-packages")
import twython
from twython import Twython
from PIL import Image, ImageChops, ImageDraw, ImageFont, ImageFilter
nap = randint(10,35)
time.sleep(nap)
path = r"publish/"
base_image = random.choice([
    x for x in os.listdir(path)
    if os.path.isfile(os.path.join(path, x))
])
filename0=(path+base_image)
def generate_the_word(infile):
        with open(infile) as f:
            contents_of_file = f.read()
        lines = contents_of_file.splitlines()
        line_number = random.randrange(0, len(lines))
        return lines[line_number]

def draw_text_with_halo(img, position, text, font, col, halo_col):
    halo = Image.new('RGBA', img.size, (0, 0, 0, 0))
    ImageDraw.Draw(halo).text(position, text, font = font, fill = halo_col)
    blurred_halo = halo.filter(ImageFilter.BLUR)
    ImageDraw.Draw(blurred_halo).text(position, text, font = font, fill = col)
    return Image.composite(img, blurred_halo, ImageChops.invert(blurred_halo))

if __name__ == '__main__':
    inp = Image.open(filename0)
    font = ImageFont.truetype("/home/jack/.fonts/Exo-Black.ttf", 40)
    text_col = (255, 255,230) # bright green
    halo_col = (0, 0, 0)   # black
    textin = (generate_the_word("wordcloud.txt"))
    i2 = draw_text_with_halo(inp, (15, 8), textin, font, text_col, halo_col)
    
    #txt = Image.new('RGBA', i.size, (255,255,255,0))

    # get a font
    fnt = ImageFont.truetype("/home/jack/.fonts/Exo-Black.ttf", 20)
    # get a drawing context
    width, height = inp.size
    marginx = 225
    marginy = 35
    x = width - marginx
    y = height - marginy
    signature_ = "The TwitterBot Project" 
    #text_col2 = (150, 255, 150) # bright green
    #halo_col2 = (0, 0, 0)   # black
    text_col2 = (255, 255,230) # bright green
    halo_col2 = (0, 0, 0)   # black
    txt=draw_text_with_halo(i2,(x,y), signature_, fnt, text_col2, halo_col2)
    out = Image.alpha_composite(i2, txt)
    out.save("tmp/TM_POST.jpg")

#removed keys for privacy reasons
CONSUMER_KEY = 'xxxxxxxxxxxxxxxxxxxxxx'
CONSUMER_SECRET = 'xxxxxxxxxxxxxxxxxx'
ACCESS_KEY = 'xxxxxxxxxxxxxxxx'
ACCESS_SECRET = 'xxxxxxx'

twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_KEY, ACCESS_SECRET)
#path = 'images/NewFolder'
f = open("art.txt")
text = f.read()
# Build the model.
text_model = markovify.Text(text)
# Print randomly-generated sentences of no more than 140 characters
#http://paulbourke.net/fractals/
STR = (text_model.make_short_sentence(140))
#STR = ("#All_in_One - #WordCloud #Create - Added ability to randomly choose an image background  #Automated")
#PATH = "/home/jack/Desktop/deep-dream-generator/notebooks/STUFF/experiment/experiment8.jpg"
PATH = "tmp/TM_POST.jpg"
# 1 , 2, 3, 12, 5, 15, 8, 6
#photo = open('/home/jack/Desktop/deep-dream-generator/notebooks/images/'+file_list[rnd]+'.jpg','rb')

photo = open(PATH,'rb')
response = twitter.upload_media(media=photo)
twitter.update_status(status=STR, media_ids=[response['media_id']])
# Out:
# Overwriting titlenpost.py
