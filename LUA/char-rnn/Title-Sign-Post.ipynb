# %%
# !sudo locate /key.py
# Out:
# /home/conda/.local/share/Steam/steamapps/common/CUPID - A free to play Visual Novel/lib/pythonlib2.7/rsa/key.pyo
# /home/conda/.local/share/Steam/steamapps/common/CUPID - A free to play Visual Novel/lib/windows-i686/Lib/pygame_sdl2/key.pyd
# /home/conda/Desktop/NoteBooks/AUDIO/isobar/build/lib/isobar/key.py
# /home/conda/Desktop/NoteBooks/AUDIO/isobar/isobar/key.py
# /home/conda/Desktop/NoteBooks/AUDIO/isobar/isobar/key.pyc
# /home/conda/Desktop/NoteBooks/PROCESSING/processing/key.pyc
# /home/conda/Desktop/NoteBooks/TEXT_NLTK/exercise-library/.virtualenv/lib/python2.7/site-packages/boto/file/key.py
# /home/conda/Desktop/NoteBooks/TEXT_NLTK/exercise-library/.virtualenv/lib/python2.7/site-packages/boto/gs/key.py
# /home/conda/Desktop/NoteBooks/TEXT_NLTK/exercise-library/.virtualenv/lib/python2.7/site-packages/boto/s3/key.py
# /home/conda/Desktop/NoteBooks/TEXT_NLTK/exercise-library/.virtualenv/lib/python2.7/site-packages/boto/sdb/db/key.py
# /home/conda/Desktop/NoteBooks/tor/GRAPHICS/key.pyc
# /home/conda/anaconda3/envs/py35/lib/python3.5/site-packages/boto/file/key.py
# /home/conda/anaconda3/envs/py35/lib/python3.5/site-packages/boto/gs/key.py
# /home/conda/anaconda3/envs/py35/lib/python3.5/site-packages/boto/s3/key.py
# /home/conda/anaconda3/envs/py35/lib/python3.5/site-packages/boto/sdb/db/key.py
# /home/conda/anaconda3/envs/python35/lib/python3.5/site-packages/boto/file/key.py
# /home/conda/anaconda3/envs/python35/lib/python3.5/site-packages/boto/gs/key.py
# /home/conda/anaconda3/envs/python35/lib/python3.5/site-packages/boto/s3/key.py
# /home/conda/anaconda3/envs/python35/lib/python3.5/site-packages/boto/sdb/db/key.py
# /home/conda/anaconda3/lib/python3.6/site-packages/boto/file/key.py
# /home/conda/anaconda3/lib/python3.6/site-packages/boto/gs/key.py
# /home/conda/anaconda3/lib/python3.6/site-packages/boto/s3/key.py
# /home/conda/anaconda3/lib/python3.6/site-packages/boto/sdb/db/key.py
# /home/conda/anaconda3/pkgs/boto-2.48.0-py35h2cfd601_1/lib/python3.5/site-packages/boto/file/key.py
# /home/conda/anaconda3/pkgs/boto-2.48.0-py35h2cfd601_1/lib/python3.5/site-packages/boto/gs/key.py
# /home/conda/anaconda3/pkgs/boto-2.48.0-py35h2cfd601_1/lib/python3.5/site-packages/boto/s3/key.py
# /home/conda/anaconda3/pkgs/boto-2.48.0-py35h2cfd601_1/lib/python3.5/site-packages/boto/sdb/db/key.py
# /home/conda/anaconda3/pkgs/boto-2.48.0-py36h6e4cd66_1/lib/python3.6/site-packages/boto/file/key.py
# /home/conda/anaconda3/pkgs/boto-2.48.0-py36h6e4cd66_1/lib/python3.6/site-packages/boto/gs/key.py
# /home/conda/anaconda3/pkgs/boto-2.48.0-py36h6e4cd66_1/lib/python3.6/site-packages/boto/s3/key.py
# /home/conda/anaconda3/pkgs/boto-2.48.0-py36h6e4cd66_1/lib/python3.6/site-packages/boto/sdb/db/key.py
# /home/jack/PycharmProjects/pycharm-community-2017.1.4/helpers/typeshed/third_party/2and3/boto/s3/key.pyi
# /home/jack/PycharmProjects/pycharm-community-2017.2/helpers/typeshed/third_party/2and3/boto/s3/key.pyi
# /home/jack/anaconda2/envs/pyth3/lib/python3.5/site-packages/boto/file/key.py
# /home/jack/anaconda2/envs/pyth3/lib/python3.5/site-packages/boto/gs/key.py
# /home/jack/anaconda2/envs/pyth3/lib/python3.5/site-packages/boto/s3/key.py
# /home/jack/anaconda2/envs/pyth3/lib/python3.5/site-packages/boto/sdb/db/key.py
# /home/jack/anaconda2/lib/python2.7/site-packages/boto/file/key.py
# /home/jack/anaconda2/lib/python2.7/site-packages/boto/file/key.pyc
# /home/jack/anaconda2/lib/python2.7/site-packages/boto/gs/key.py
# /home/jack/anaconda2/lib/python2.7/site-packages/boto/gs/key.pyc
# /home/jack/anaconda2/lib/python2.7/site-packages/boto/s3/key.py
# /home/jack/anaconda2/lib/python2.7/site-packages/boto/s3/key.pyc
# /home/jack/anaconda2/lib/python2.7/site-packages/boto/sdb/db/key.py
# /home/jack/anaconda2/lib/python2.7/site-packages/boto/sdb/db/key.pyc
# /home/jack/anaconda2/lib/python2.7/site-packages/isobar-0.0.1-py2.7.egg/isobar/key.py
# /home/jack/anaconda2/lib/python2.7/site-packages/isobar-0.0.1-py2.7.egg/isobar/key.pyc
# /home/jack/anaconda2/lib/python2.7/site-packages/music21/key.py
# /home/jack/anaconda2/lib/python2.7/site-packages/music21/key.pyc
# /home/jack/anaconda2/lib/python2.7/site-packages/rsa/key.py
# /home/jack/anaconda2/lib/python2.7/site-packages/rsa/key.pyc
# /home/jack/anaconda2/pkgs/boto-2.48.0-py27_1/lib/python2.7/site-packages/boto/file/key.py
# /home/jack/anaconda2/pkgs/boto-2.48.0-py27_1/lib/python2.7/site-packages/boto/file/key.pyc
# /home/jack/anaconda2/pkgs/boto-2.48.0-py27_1/lib/python2.7/site-packages/boto/gs/key.py
# /home/jack/anaconda2/pkgs/boto-2.48.0-py27_1/lib/python2.7/site-packages/boto/gs/key.pyc
# /home/jack/anaconda2/pkgs/boto-2.48.0-py27_1/lib/python2.7/site-packages/boto/s3/key.py
# /home/jack/anaconda2/pkgs/boto-2.48.0-py27_1/lib/python2.7/site-packages/boto/s3/key.pyc
# /home/jack/anaconda2/pkgs/boto-2.48.0-py27_1/lib/python2.7/site-packages/boto/sdb/db/key.py
# /home/jack/anaconda2/pkgs/boto-2.48.0-py27_1/lib/python2.7/site-packages/boto/sdb/db/key.pyc
# /home/jack/anaconda2/pkgs/boto-2.48.0-py27h9556ac2_1/lib/python2.7/site-packages/boto/file/key.py
# /home/jack/anaconda2/pkgs/boto-2.48.0-py27h9556ac2_1/lib/python2.7/site-packages/boto/file/key.pyc
# /home/jack/anaconda2/pkgs/boto-2.48.0-py27h9556ac2_1/lib/python2.7/site-packages/boto/gs/key.py
# /home/jack/anaconda2/pkgs/boto-2.48.0-py27h9556ac2_1/lib/python2.7/site-packages/boto/gs/key.pyc
# /home/jack/anaconda2/pkgs/boto-2.48.0-py27h9556ac2_1/lib/python2.7/site-packages/boto/s3/key.py
# /home/jack/anaconda2/pkgs/boto-2.48.0-py27h9556ac2_1/lib/python2.7/site-packages/boto/s3/key.pyc
# /home/jack/anaconda2/pkgs/boto-2.48.0-py27h9556ac2_1/lib/python2.7/site-packages/boto/sdb/db/key.py
# /home/jack/anaconda2/pkgs/boto-2.48.0-py27h9556ac2_1/lib/python2.7/site-packages/boto/sdb/db/key.pyc
# /home/jack/anaconda2/pkgs/boto-2.48.0-py35h2cfd601_1/lib/python3.5/site-packages/boto/file/key.py
# /home/jack/anaconda2/pkgs/boto-2.48.0-py35h2cfd601_1/lib/python3.5/site-packages/boto/gs/key.py
# /home/jack/anaconda2/pkgs/boto-2.48.0-py35h2cfd601_1/lib/python3.5/site-packages/boto/s3/key.py
# /home/jack/anaconda2/pkgs/boto-2.48.0-py35h2cfd601_1/lib/python3.5/site-packages/boto/sdb/db/key.py
# /home/jack/anaconda3/lib/python3.6/site-packages/boto/file/key.py
# /home/jack/anaconda3/lib/python3.6/site-packages/boto/gs/key.py
# /home/jack/anaconda3/lib/python3.6/site-packages/boto/s3/key.py
# /home/jack/anaconda3/lib/python3.6/site-packages/boto/sdb/db/key.py
# /home/jack/anaconda3/pkgs/boto-2.48.0-py36h6e4cd66_1/lib/python3.6/site-packages/boto/file/key.py
# /home/jack/anaconda3/pkgs/boto-2.48.0-py36h6e4cd66_1/lib/python3.6/site-packages/boto/gs/key.py
# /home/jack/anaconda3/pkgs/boto-2.48.0-py36h6e4cd66_1/lib/python3.6/site-packages/boto/s3/key.py
# /home/jack/anaconda3/pkgs/boto-2.48.0-py36h6e4cd66_1/lib/python3.6/site-packages/boto/sdb/db/key.py
# /home/jack/git/GoogleAppEngine/google_appengine/google/appengine/ext/ndb/key.py
# /home/jack/git/GoogleAppEngine/google_appengine/lib/rsa/rsa/key.py
# /home/jack/git/GoogleAppEngine/google_appengine/lib/rsa/rsa/key.pyc
# /home/jack/git/pygame/symbian/lib/key.py
# /home/jack/hidden/key.py
# /home/jack/hidden/key.pyc
# /home/jack/pygame/.hg/store/data/pygame/key.py.i
# /home/jack/pygame/.hg/store/data/symbian/lib/key.py.i
# /home/jack/pygame/symbian/lib/key.py
# /usr/local/lib/python2.7/dist-packages/boto/file/key.py
# /usr/local/lib/python2.7/dist-packages/boto/file/key.pyc
# /usr/local/lib/python2.7/dist-packages/boto/gs/key.py
# /usr/local/lib/python2.7/dist-packages/boto/gs/key.pyc
# /usr/local/lib/python2.7/dist-packages/boto/s3/key.py
# /usr/local/lib/python2.7/dist-packages/boto/s3/key.pyc
# /usr/local/lib/python2.7/dist-packages/boto/sdb/db/key.py
# /usr/local/lib/python2.7/dist-packages/boto/sdb/db/key.pyc
# /usr/local/lib/python2.7/dist-packages/glumpy/app/window/key.py
# /usr/local/lib/python2.7/dist-packages/glumpy/app/window/key.pyc
# /usr/local/lib/python2.7/dist-packages/pygame-1.9.4.dev0-py2.7-linux-x86_64.egg/pygame/key.py
# /usr/local/lib/python2.7/dist-packages/pygame-1.9.4.dev0-py2.7-linux-x86_64.egg/pygame/key.pyc
# /usr/local/lib/python2.7/dist-packages/rsa/key.py
# /usr/local/lib/python2.7/dist-packages/rsa/key.pyc
# /usr/share/pycharm/helpers/typeshed/third_party/2and3/boto/s3/key.pyi

# %%
sys.path.insert(0, "/home/jack/hidden")
import key
CONSUMER_KEY = key.twiter()[0]
print CONSUMER_KEY
# Out:
# CeiWVwKXfsNq6tIkJJENJyb5c

# %%
#ONE TIME MANUAL POSTS
#!/home/jack/anaconda2/python
import random
from random import randint
import time
import markovify
import os
import sys
sys.path.insert(0, "/home/jack/hidden")
import key
#sys.path.insert(1, "/home/jack/Desktop/pycode/vpython2")
import twython
from twython import Twython
from PIL import Image, ImageChops, ImageDraw, ImageFont, ImageFilter

#custom = "/home/jack/Desktop/post/ball009.png"
#custom = "/home/jack/Desktop/PROCESSING/color-wander/images/kk.png"
#custom = PAth+"gg.png"
#custom = "junk2/PalletteTemp.jpg"

#PATH = "clouddream/backup/deepdream/images/"
#custom = PATH+"8conv3fc_DSN-pool4-100-mountain.jpg"

custom = "Last-GRU-network-loss-1.2412-plot-for-Directory-kolbrin_2018-0724094637.png"
#custom = "/home/jack/Desktop/GRAPHICS/otoro-net/0002jav.png"

#custom = "/home/jack/Desktop/GRAPHICS/otoro-net/0003jav.png"
#custom = "/home/jack/Desktop/GRAPHICS/otoro-net/0004jav.png"
#custom = "junk/PalletteTemp.png"
filename0=(custom)
def generate_the_word(infile):
        with open(infile) as f:
            contents_of_file = f.read()
        lines = contents_of_file.splitlines()
        line_number = random.randrange(0, len(lines))
        return lines[line_number]

def draw_blurred_back(img, position, text, font, col, halo_col):
    halo = Image.new('RGBA', img.size, (0, 0, 0, 0))
    ImageDraw.Draw(halo).text(position, text, font = font, fill = halo_col)
    blurred_halo = halo.filter(ImageFilter.BLUR)
    ImageDraw.Draw(blurred_halo).text(position, text, font = font, fill = col)
    return Image.composite(img, blurred_halo, ImageChops.invert(blurred_halo))

if __name__ == '__main__':
    inp = Image.open(filename0)
    inp = inp.resize((640,640), Image.ANTIALIAS)
    font = ImageFont.truetype("/home/jack/.fonts/Exo-Black.ttf", 30)
    text_title = (255, 255,230) # bright green
    blur_title = (0, 0, 0)   # black
    #textin = (generate_the_word("wordcloud.txt"))
    i2 = draw_blurred_back(inp, (115, 10), "LSTM Model Training Plots", font, text_title, blur_title)
    font0 = ImageFont.truetype("/home/jack/.fonts/Exo-Black.ttf", 20)
    i2 = draw_blurred_back(i2, (115, 100), "GRU model", font0, text_title, blur_title)    
    i2 = draw_blurred_back(i2, (115, 120), "1662 Samples", font0, text_title, blur_title)    
    
    #txt = Image.new('RGBA', i.size, (255,255,255,0))

    # get a font
    fnt = ImageFont.truetype("/home/jack/.fonts/Exo-Black.ttf", 20)
    # get a drawing context
    signature_ = "@Jacknorthrup Instagram and @jacklnorthrup TwitterBot Project" 
    #get length in pixel of signature_
    sizeS,ln = fnt.getsize(signature_)
    #add 15 pixels to right border
    pt = sizeS+25
    width, height = inp.size
    #marginx starting point of signature_
    marginx = pt
    #bottom margin
    marginy = 30
    x = width - marginx
    y = height - marginy
    

    text_sig = (255, 255,230) # bright green
    blur_sig = (0, 0, 0)   # black
    txt=draw_blurred_back(i2,(x,y), signature_, fnt, text_sig, blur_sig)
    out = Image.alpha_composite(i2, txt)
    out.save("TM_POST.png")

#removed keys for privacy reasons
CONSUMER_KEY = key.twiter()[0]
CONSUMER_SECRET = key.twiter()[1]
ACCESS_KEY = key.twiter()[2]
ACCESS_SECRET = key.twiter()[3]

twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_KEY, ACCESS_SECRET)
#f = open("codetalk.txt")
#text = f.read()
#text_model = markovify.Text(text)
#STR = (text_model.make_short_sentence(140))
STR = ("Text Generation Model - notice the abnormalies from experimentation")
# USE BELOW for no signature
#PATH = "/home/jack/Desktop/deep-dream-generator/notebooks/STUFF/experiment/experiment8.jpg"
PATH = "TM_POST.png"
#photo = open('/home/jack/Desktop/deep-dream-generator/notebooks/images/'+file_list[rnd]+'.jpg','rb')
image = open(PATH,'rb')
response = twitter.upload_media(media=image)
twitter.update_status(status=STR, media_ids=[response['media_id']])
# Out:
# {u'contributors': None,
#  u'coordinates': None,
#  u'created_at': u'Thu Jul 26 01:45:17 +0000 2018',
#  u'entities': {u'hashtags': [],
#   u'media': [{u'display_url': u'pic.twitter.com/4EP8j9w5XK',
#     u'expanded_url': u'https://twitter.com/JackLNorthrup/status/1022296768271118341/photo/1',
#     u'id': 1022296764882214912,
#     u'id_str': u'1022296764882214912',
#     u'indices': [68, 91],
#     u'media_url': u'http://pbs.twimg.com/media/Di_tfcXV4AAkGIj.png',
#     u'media_url_https': u'https://pbs.twimg.com/media/Di_tfcXV4AAkGIj.png',
#     u'sizes': {u'large': {u'h': 640, u'resize': u'fit', u'w': 640},
#      u'medium': {u'h': 640, u'resize': u'fit', u'w': 640},
#      u'small': {u'h': 640, u'resize': u'fit', u'w': 640},
#      u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#     u'type': u'photo',
#     u'url': u'https://t.co/4EP8j9w5XK'}],
#   u'symbols': [],
#   u'urls': [],
#   u'user_mentions': []},
#  u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/4EP8j9w5XK',
#     u'expanded_url': u'https://twitter.com/JackLNorthrup/status/1022296768271118341/photo/1',
#     u'id': 1022296764882214912,
#     u'id_str': u'1022296764882214912',
#     u'indices': [68, 91],
#     u'media_url': u'http://pbs.twimg.com/media/Di_tfcXV4AAkGIj.png',
#     u'media_url_https': u'https://pbs.twimg.com/media/Di_tfcXV4AAkGIj.png',
#     u'sizes': {u'large': {u'h': 640, u'resize': u'fit', u'w': 640},
#      u'medium': {u'h': 640, u'resize': u'fit', u'w': 640},
#      u'small': {u'h': 640, u'resize': u'fit', u'w': 640},
#      u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#     u'type': u'photo',
#     u'url': u'https://t.co/4EP8j9w5XK'}]},
#  u'favorite_count': 0,
#  u'favorited': False,
#  u'geo': None,
#  u'id': 1022296768271118341,
#  u'id_str': u'1022296768271118341',
#  u'in_reply_to_screen_name': None,
#  u'in_reply_to_status_id': None,
#  u'in_reply_to_status_id_str': None,
#  u'in_reply_to_user_id': None,
#  u'in_reply_to_user_id_str': None,
#  u'is_quote_status': False,
#  u'lang': u'en',
#  u'place': None,
#  u'possibly_sensitive': False,
#  u'retweet_count': 0,
#  u'retweeted': False,
#  u'source': u'<a href="http://blogblocks.org" rel="nofollow">jackwatch</a>',
#  u'text': u'Text Generation Model - notice the abnormalies from experimentation https://t.co/4EP8j9w5XK',
#  u'truncated': False,
#  u'user': {u'contributors_enabled': False,
#   u'created_at': u'Wed May 11 16:01:29 +0000 2011',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'Overcome with addictions: PHP, Python, Nodejs, JavaScript, P5.js, Processing.js, Ruby, MySql, Mongo, HTML, CSS, Docker, Bash scripting, C++, Linux, Android.',
#   u'entities': {u'description': {u'urls': []},
#    u'url': {u'urls': [{u'display_url': u'jacknorthrup.com',
#       u'expanded_url': u'http://jacknorthrup.com',
#       u'indices': [0, 23],
#       u'url': u'https://t.co/SFgB3ME7hP'}]}},
#   u'favourites_count': 2006,
#   u'follow_request_sent': False,
#   u'followers_count': 2733,
#   u'following': False,
#   u'friends_count': 3213,
#   u'geo_enabled': True,
#   u'has_extended_profile': False,
#   u'id': 296906916,
#   u'id_str': u'296906916',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 36,
#   u'location': u'Philippines via USA',
#   u'name': u'Jack Northrup',
#   u'notifications': False,
#   u'profile_background_color': u'C0DEED',
#   u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#   u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#   u'profile_background_tile': True,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/296906916/1502958210',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/2765370268/48e94b4ba63cc542d5e0967136165bec_normal.png',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/2765370268/48e94b4ba63cc542d5e0967136165bec_normal.png',
#   u'profile_link_color': u'F70A1D',
#   u'profile_sidebar_border_color': u'FFFFFF',
#   u'profile_sidebar_fill_color': u'DDEEF6',
#   u'profile_text_color': u'333333',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'JackLNorthrup',
#   u'statuses_count': 7098,
#   u'time_zone': None,
#   u'translator_type': u'none',
#   u'url': u'https://t.co/SFgB3ME7hP',
#   u'utc_offset': None,
#   u'verified': False}}

# %%
# !showme TM_POST.png

# %%
# Simple bijective function
#   Basically encodes any integer into a base(n) string,
#     where n is ALPHABET.length.
#   Based on pseudocode from http://stackoverflow.com/questions/742013/how-to-code-a-url-shortener/742047#742047

ALPHABET = list("abcdefghijklmnopqrstuvwxyz ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789")
  # make your own alphabet using:
  # (('a'..'z').to_a + ('A'..'Z').to_a + (0..9).to_a).shuffle.join

def bijective_encode(i):
    # from http://refactormycode.com/codes/125-base-62-encoding
    if i == 0:
        return ALPHABET[0]
    s = ''
    base = len(ALPHABET)
    while i > 0:
        s += ALPHABET[i % base]
        i /= base
    return s[::-1] # reverse string


def bijective_decode(s):
    # based on base2dec() in Tcl translation 
    # at http://rosettacode.org/wiki/Non-decimal_radices/Convert#Ruby
    i = 0
    base = len(ALPHABET)
    for char in s:
        i = i * base + ALPHABET.index(char)
    return i

# Two little demos:

numbers = 1234567890
result = bijective_encode(numbers)
print result #xyz

letters = 'Jack Northrup'
new_number = bijective_decode(letters)
print new_number #66
# Out:
# bpxvMS
# 140732912634465149888163
